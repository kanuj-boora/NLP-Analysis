# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('./wednesday_data/corpus.pkl')
data
# Out:
#                                             transcript
# E01  Original release date: November 23, 2022 Wedne...
# E02  Original release date: November 23, 2022 Wedne...
# E03  Original release date: November 23, 2022 Wedne...
# E04  Original release date: November 23, 2022 Wedne...
# E05  Original release date: November 23, 2022 32 ye...
# E06  Original release date: November 23, 2022 Wedne...
# E07  Original release date: November 23, 2022 At Ma...
# E08  Original release date: November 23, 2022 Wedne...

# %%
# Extract only E01 text
ep01_text = data.transcript.loc['E01']
ep01_text[:200]
# Out:
# 'Original release date: November\xa023,\xa02022 Wednesday Addams, a high-school student, finds her brother\xa0Pugsley\xa0tied up in a locker. She sees a psychic vision of his bullies whom she attempts to kill in r'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for E01, take a look at it
ep01_dict = markov_chain(ep01_text)
ep01_dict
# Out:
# {'Original': ['release'],
#  'release': ['date:'],
#  'date:': ['November\xa023,\xa02022'],
#  'November\xa023,\xa02022': ['Wednesday'],
#  'Wednesday': ['Addams,',
#   'is',
#   'meets',
#   'meet',
#   'has',
#   'is',
#   'always',
#   'to',
#   'and',
#   'was'],
#  'Addams,': ['a', 'time'],
#  'a': ['high-school',
#   'locker.',
#   'psychic',
#   'school',
#   'hiker',
#   'sentient',
#   'falling',
#   'vision',
#   'closed',
#   'magical',
#   'good',
#   'polite',
#   'problem',
#   'werewolf.',
#   'beautiful',
#   'unique',
#   'line',
#   'unique',
#   'very',
#   'relationship',
#   'therapist',
#   'week.',
#   'little',
#   'hugger.',
#   'uniform.',
#   'tour',
#   'part',
#   'version',
#   'kid',
#   'pentagon.',
#   'wiki',
#   'living',
#   'small',
#   'soul-sucking',
#   'moment.',
#   'brilliant',
#   'little',
#   'symbol',
#   'housewife,',
#   'family.',
#   'kind',
#   'leg',
#   'warning.',
#   'goddamn',
#   'rainbow',
#   'day',
#   'foreign',
#   'bad',
#   'little',
#   'few',
#   'privilege,',
#   'right.',
#   'brisk',
#   'shuttle',
#   'tad',
#   'clean',
#   'military',
#   'school',
#   'run',
#   'concussion,',
#   'nasty',
#   'mixture',
#   'few',
#   'plan.',
#   'nervous',
#   'six-month',
#   'seat.',
#   'hobby',
#   'worthy',
#   'relationship',
#   'safe',
#   'waste',
#   'place',
#   'knife',
#   'sword',
#   'boy,',
#   'testicle.',
#   'favor.',
#   'valuable',
#   'life',
#   'teen',
#   '“thank',
#   'habit',
#   'hobby.',
#   'quad',
#   'quad',
#   'seizure,',
#   'temperamental',
#   'mind',
#   'tri-wing',
#   'four-millimeter',
#   'taxi.',
#   'phone.',
#   'slave',
#   'need-to-know',
#   'valve',
#   'Nevermore',
#   'need-to-know',
#   'to-go',
#   'Nevermore',
#   'special',
#   'normie?',
#   'Tibetan',
#   'monk?',
#   'customer,',
#   'minute,',
#   'word',
#   'few',
#   'school.',
#   'chance',
#   'lone',
#   'mate.',
#   'scorpion',
#   'pet.',
#   'hand.',
#   'slave',
#   'cover.',
#   'freebie.',
#   'hugger.',
#   'whole',
#   'curfew.',
#   'student',
#   'powerful',
#   'murderer,',
#   'homicidal',
#   'dark',
#   'monster',
#   'makeover,',
#   'good',
#   'stranger',
#   'group',
#   'fungal',
#   'mission'],
#  'high-school': ['student,'],
#  'student,': ['finds'],
#  'finds': ['her'],
#  'her': ['brother\xa0Pugsley\xa0tied',
#   'in',
#   'roommate',
#   'complete',
#   'court-ordered',
#   'escape',
#   'but',
#   'family,',
#   'schedule,',
#   'a',
#   'crown’s',
#   'sleep.',
#   'casket.',
#   'way',
#   'a',
#   'mother,'],
#  'brother\xa0Pugsley\xa0tied': ['up'],
#  'up': ['in', 'along', 'noise-cancelling', 'at', 'and', 'on', 'at'],
#  'in': ['a',
#   'revenge',
#   'Nevermore',
#   'underfunded',
#   'time',
#   'following',
#   'your',
#   'love.',
#   'a',
#   'the',
#   'five',
#   'Jericho.',
#   'excellent',
#   '1791',
#   'your',
#   'participating',
#   'tribal',
#   'black',
#   'this',
#   'the',
#   'your',
#   'love,',
#   'that',
#   'July.',
#   'my',
#   'Addams.',
#   'your',
#   'their',
#   'black',
#   'somewhere.',
#   'a',
#   'Europe,',
#   'her',
#   'your',
#   'here',
#   'the',
#   'these',
#   'the',
#   'Italian.',
#   'Jericho.',
#   'a',
#   'the',
#   'a',
#   'here?',
#   'their',
#   'distance]',
#   'distance]',
#   'solitary.',
#   'packs.',
#   'time.',
#   'an',
#   'the',
#   'danger.',
#   'danger.',
#   'the',
#   'it.',
#   'mind.'],
#  'locker.': ['She'],
#  'She': ['sees', 'meets', 'can', 'used', 'eats', 'was', 'had', 'needs', 'was'],
#  'sees': ['a'],
#  'psychic': ['vision'],
#  'vision': ['of', 'of'],
#  'of': ['his',
#   'Rowan’s',
#   'adolescents',
#   'you',
#   'the',
#   'the',
#   'the',
#   'putting',
#   'woe.”',
#   'their',
#   'themselves.',
#   'disdain.',
#   'outcasts',
#   'them',
#   'knuckleheads',
#   'the',
#   'my',
#   'pets.',
#   'meaningless',
#   'running',
#   'obsidian,',
#   'our',
#   'your',
#   'him?',
#   'the',
#   'the',
#   'the',
#   'my',
#   'this',
#   'color',
#   'outcasts.',
#   'rage,',
#   'the',
#   'the',
#   '“La',
#   'neroli',
#   'the',
#   'business',
#   'time.',
#   'your',
#   'Viper',
#   'this',
#   'the',
#   'theme',
#   'scaring',
#   'people?',
#   'a',
#   'espresso.',
#   'its',
#   'Machiavelli.',
#   'luck.',
#   'these',
#   'stupid',
#   'this,',
#   'this.',
#   'advice.',
#   'him?',
#   'the',
#   'my',
#   'finding',
#   'freak',
#   'them',
#   'him.',
#   'us',
#   'this',
#   'some',
#   'the',
#   'an',
#   'every',
#   'the',
#   'Fireflies.'],
#  'his': ['bullies', 'defense.', 'neck.', 'afternoon', 'daughter', 'compound,'],
#  'bullies': ['whom', 'another', 'your'],
#  'whom': ['she'],
#  'she': ['attempts',
#   'bullies',
#   'is',
#   'greatly',
#   'survives',
#   'murdered.',
#   'tripped',
#   'put',
#   'says',
#   'was',
#   'died.',
#   'ever',
#   'will'],
#  'attempts': ['to', 'to'],
#  'to': ['kill',
#   'enroll',
#   'watch',
#   'help',
#   'the',
#   'kill',
#   'put',
#   'confess',
#   'my',
#   'me.',
#   'torture',
#   'dream',
#   'music]',
#   'them.',
#   'file',
#   'get',
#   'get',
#   'hold',
#   'say',
#   'your',
#   'Ophelia',
#   'color.',
#   'you?',
#   'the',
#   'pick',
#   'educate',
#   'send',
#   'get',
#   'the',
#   'fill',
#   'royalty.',
#   'date',
#   'my',
#   'be',
#   'contact',
#   'go.',
#   'love',
#   'conjure',
#   'heart.',
#   'you',
#   'tell',
#   'be',
#   'Nevermore.',
#   'my',
#   'my',
#   'your',
#   'you.',
#   'mind.',
#   'gossip',
#   'use',
#   'make',
#   'greet',
#   'return',
#   'match',
#   'each',
#   'go',
#   'Jericho',
#   'yourself,',
#   'challenge',
#   'come',
#   'his',
#   'Wednesday.',
#   'invoke',
#   'be',
#   'Bianca',
#   'extract',
#   'be',
#   'mush?',
#   'see',
#   'play',
#   'hide',
#   'the',
#   'claw',
#   'spy',
#   'pull',
#   'claw',
#   'me.',
#   'escape',
#   'prevent',
#   'take',
#   'dump',
#   'a',
#   'help',
#   'deal',
#   'constructive',
#   'hear',
#   'uncomfortable',
#   'Nevermore.',
#   'fix',
#   'make',
#   'be',
#   'technology.',
#   'decapitate',
#   'Burlington?',
#   'drive',
#   'devote',
#   'zealots',
#   'go.',
#   'need',
#   'the',
#   'fly',
#   'Milwaukee,',
#   'see',
#   'never',
#   'show',
#   'use',
#   'not',
#   'be',
#   'technology?',
#   'help',
#   'use',
#   'drive',
#   'the',
#   'her.',
#   'you?',
#   'interrupt.',
#   'go',
#   'lose',
#   'have',
#   'people',
#   'go.',
#   'explain,',
#   'kill',
#   'kill',
#   'stop',
#   'Nevermore,',
#   'admit,',
#   'love',
#   'take',
#   'find',
#   'end',
#   'this',
#   'his',
#   'drop'],
#  'kill': ['in', 'her', 'or', 'you.', 'me'],
#  'revenge': ['but'],
#  'but': ['gets',
#   'is',
#   'is',
#   'I',
#   'without',
#   'it',
#   'given',
#   'who’s',
#   'here',
#   'the',
#   'clueless.',
#   'sometimes',
#   'you',
#   'we',
#   'I',
#   'no.',
#   'a',
#   'I’ve',
#   'this',
#   'you’re',
#   'everyone'],
#  'gets': ['expelled.', 'to'],
#  'expelled.': ['Her', 'That'],
#  'Her': ['parents,\xa0Morticia\xa0and\xa0Gomez,', 'name'],
#  'parents,\xa0Morticia\xa0and\xa0Gomez,': ['decide'],
#  'decide': ['to'],
#  'enroll': ['her'],
#  'Nevermore': ['Academy,',
#   'is',
#   'doesn’t',
#   'was',
#   'has',
#   'gossip.',
#   'welcome.',
#   'students',
#   'kid',
#   'freak',
#   'is'],
#  'Academy,': ['a'],
#  'school': ['for', 'for', 'for', 'for', 'has', 'full', 'counselor.', 'and'],
#  'for': ['outcasts.',
#   'her.',
#   'you?',
#   'outcasts?',
#   'long.',
#   'any',
#   'decades.',
#   'Nevermore',
#   'your',
#   'the',
#   'the',
#   'my',
#   'the',
#   'hot',
#   'a',
#   'instance,',
#   'your',
#   'the',
#   'our',
#   'people',
#   'another',
#   'mass',
#   'murder.',
#   'his',
#   'a',
#   'all',
#   'someone.'],
#  'outcasts.': ['Meanwhile,', 'My', 'But'],
#  'Meanwhile,': ['a'],
#  'hiker': ['is'],
#  'is': ['killed',
#   'nearly',
#   'saved',
#   'apprehended',
#   'murdered',
#   'a',
#   'me.',
#   'like',
#   'fine.',
#   'certainly',
#   'full',
#   'trying',
#   'that',
#   'Enid',
#   'the',
#   'my',
#   'back.',
#   'my',
#   'your',
#   'even.',
#   'to',
#   'on',
#   'beneath',
#   'below',
#   'a',
#   'a',
#   'kill',
#   'to',
#   'a',
#   'strictly',
#   'smart,',
#   'drip.',
#   'for',
#   'Burlington.',
#   'that',
#   'our',
#   'your',
#   'incredibly',
#   'ground',
#   'next-level.',
#   'mandatory.',
#   'gonna',
#   'even'],
#  'killed': ['by', 'by', 'a'],
#  'by': ['an',
#   'a',
#   'Bianca’s',
#   'principal',
#   'the',
#   'people',
#   'visions.',
#   'Édith',
#   'Roy',
#   'her',
#   'the',
#   'latent',
#   'her.',
#   'the',
#   '12:00.',
#   'a'],
#  'an': ['unknown',
#   'exception.',
#   'arm',
#   'hour',
#   'outcast',
#   'imaginative',
#   'author?',
#   'emergency.',
#   'hour',
#   'entire',
#   'Addams?',
#   'accident.',
#   'extra',
#   'hour.',
#   'obsession',
#   'attempted',
#   'unlikely',
#   'abandoned'],
#  'unknown': ['creature'],
#  'creature': ['near'],
#  'near': ['Nevermore.'],
#  'Nevermore.': ['Wednesday’s',
#   'However,',
#   'Won’t',
#   'That',
#   'I',
#   'Didn’t',
#   'I',
#   'She'],
#  'Wednesday’s': ['parents', 'perfect'],
#  'parents': ['release\xa0Thing,', 'that', 'pulled', 'aren’t'],
#  'release\xa0Thing,': ['a'],
#  'sentient': ['disembodied'],
#  'disembodied': ['hand,'],
#  'hand,': ['to'],
#  'watch': ['over', 'your'],
#  'over': ['her.', 'here', 'there.', 'there,', 'a', 'ice.', 'until…', 'there?'],
#  'her.': ['She', 'Why?', 'You’ll', 'I'],
#  'meets': ['her', 'Tyler,'],
#  'roommate': ['Enid,'],
#  'Enid,': ['her', 'please'],
#  'complete': ['opposite,'],
#  'opposite,': ['and'],
#  'and': ['duels',
#   'taken',
#   'Wednesday',
#   'Wednesday',
#   'feel',
#   'me,',
#   'your',
#   'we’ve',
#   'then',
#   'give',
#   'your',
#   'Scales.',
#   'white.',
#   'TikTok.',
#   'I',
#   'weak.',
#   'you',
#   'find',
#   'I',
#   'arm',
#   'the',
#   'I’m',
#   'no',
#   'no',
#   'practiced',
#   'white.',
#   'self-disgust.',
#   'saw',
#   'I',
#   'they',
#   'notorious.',
#   'we',
#   'seek.',
#   'was',
#   'saved',
#   'bergamot',
#   'Father',
#   'you',
#   'your',
#   'had',
#   'take',
#   'mutual',
#   'my',
#   'showed',
#   'suggested',
#   'her',
#   'know',
#   'it',
#   'a',
#   'call',
#   'she',
#   'you’re',
#   'start',
#   'we',
#   'made',
#   'safe',
#   'cross',
#   'everyone',
#   'was',
#   'boy',
#   'the',
#   'Ellie',
#   'Frank’s',
#   'Ellie',
#   'Ellie',
#   'flooded',
#   'Ellie'],
#  'duels': ['with'],
#  'with': ['Bianca,',
#   'outcasts.',
#   'your',
#   'the',
#   'the',
#   'a',
#   'her',
#   'better',
#   'insipid',
#   'me.',
#   'hospitality.',
#   'your',
#   'your',
#   'your',
#   'a',
#   'a',
#   'no',
#   'me.',
#   'you.',
#   'a',
#   'me.',
#   'this',
#   'horses',
#   'a',
#   'a'],
#  'Bianca,': ['the'],
#  'the': ['popular',
#   'school.',
#   'local',
#   'monster.',
#   'sadism.',
#   'satisfying',
#   'magic',
#   'cold',
#   'perfect',
#   'perfect',
#   'fencing',
#   'Dark',
#   'Séance',
#   'ones',
#   'job',
#   'day',
#   '13th.',
#   'world,',
#   'day?',
#   'opportunity.',
#   'school,',
#   'board',
#   'first',
#   'one',
#   'flesh',
#   'registrar’s',
#   'way.',
#   'sanitized',
#   'quad.',
#   'four',
#   'Fangs,',
#   'closest',
#   'beginning',
#   'semester.',
#   'number',
#   'dirt',
#   'contrary.',
#   'bodies',
#   'car?',
#   'minute',
#   'crystal',
#   'first',
#   'rest',
#   'torso',
#   'lake.',
#   'rest',
#   'parts',
#   'profile',
#   'other',
#   'woods.',
#   'foreseeable',
#   'press?',
#   'bear',
#   'hell',
#   'same,',
#   'following',
#   'way,',
#   'mud.',
#   'old',
#   'favor.',
#   'right',
#   'story',
#   'local',
#   'weekends.',
#   'psychopath',
#   'self-appointed',
#   'final',
#   'way.',
#   'tool',
#   'patriarchy,',
#   'favor.',
#   'last',
#   'rich',
#   'inspired',
#   'crematorium.',
#   'big',
#   'faint',
#   'rest',
#   'semester,',
#   'second',
#   'Weathervane',
#   'notes',
#   'world,',
#   'world',
#   'pool.',
#   'old',
#   'world',
#   'life',
#   'manuscripts',
#   'powder',
#   'rest',
#   'session.',
#   'afternoon,',
#   'hell',
#   'uniform.',
#   'espresso',
#   'instructions',
#   'native',
#   'deal.',
#   'way.',
#   'pot.',
#   'wild?',
#   'buckled',
#   'hell’s',
#   'apple',
#   'tree.',
#   'driver’s',
#   'hell',
#   'window?',
#   'rest',
#   'great',
#   'best',
#   'problem',
#   'week',
#   'others',
#   'Harvest',
#   'station,',
#   'lucky',
#   'parking',
#   'fireworks',
#   'reason',
#   'street.',
#   'crowd.',
#   'one',
#   'quiet',
#   'picture.',
#   'school',
#   'school,',
#   'dark.',
#   'target',
#   'center',
#   'full',
#   'room',
#   'infected.',
#   'planet,',
#   'Loft.'],
#  'popular': ['girl,'],
#  'girl,': ['after', 'Bianca', 'Wednesday,'],
#  'after': ['she', 'being', 'my', 'our', 'Halloween.', 'a'],
#  'another': ['boy,', 'hour.'],
#  'boy,': ['Rowan.', 'and'],
#  'Rowan.': ['Later,', 'Maybe', 'I', 'Rowan.', '[tense,'],
#  'Later,': ['Wednesday', 'Tyler', 'Joel'],
#  'nearly': ['killed'],
#  'falling': ['gargoyle'],
#  'gargoyle': ['but', 'coming'],
#  'saved': ['by', 'myself.', 'me', 'by'],
#  'Bianca’s': ['ex-boyfriend'],
#  'ex-boyfriend': ['Xavier.'],
#  'Xavier.': ['After'],
#  'After': ['escaping', 'what', 'Joel'],
#  'escaping': ['her'],
#  'court-ordered': ['therapy'],
#  'therapy': ['session,', 'sessions?'],
#  'session,': ['Wednesday'],
#  'Tyler,': ['who', 'by', 'the'],
#  'who': ['agrees',
#   'they',
#   'gets',
#   'understand',
#   'got',
#   'kills',
#   'want',
#   'crochets',
#   'hate',
#   'got'],
#  'agrees': ['to'],
#  'help': ['her', 'you', 'you', 'that', 'her?', 'me'],
#  'escape': ['from', 'this', 'this'],
#  'from': ['Nevermore.',
#   'a',
#   'my',
#   'me',
#   'my',
#   'being',
#   'afar.',
#   'happening.',
#   'your',
#   'me.',
#   'the',
#   'this',
#   'a',
#   'when',
#   'you.',
#   'the'],
#  'However,': ['she'],
#  'apprehended': ['by'],
#  'principal': ['Larissa'],
#  'Larissa': ['Weems'],
#  'Weems': ['and'],
#  'taken': ['back'],
#  'back': ['to', 'in', 'so', 'off.', 'in'],
#  'school.': ['Later,', 'It’s', 'There', '[door', 'Did'],
#  'Tyler': ['and'],
#  'meet': ['at', 'twice', 'your'],
#  'at': ['the',
#   'summer',
#   'me.',
#   'your',
#   'normie',
#   'the',
#   'you,',
#   'you,',
#   'least',
#   '10:00,',
#   'bonding',
#   'home?',
#   'Pilgrim',
#   'this.',
#   'all.',
#   'this,',
#   'Nevermore.',
#   'Nevermore.',
#   'the',
#   'all'],
#  'local': ['fair,', 'town?'],
#  'fair,': ['and'],
#  'has': ['a', 'a', 'to', 'given', 'that'],
#  'Rowan’s': ['death.'],
#  'death.': ['Rowan'],
#  'Rowan': ['attempts', 'doesn’t'],
#  'murdered': ['by'],
#  'monster.': ['*', 'As'],
#  '*': ['*', '*', '[jauntily', 'Name*'],
#  '[jauntily': ['macabre', 'macabre', 'macabre'],
#  'macabre': ['music', 'theme', 'outro'],
#  'music': ['playing]',
#   'swells,',
#   'playing]',
#   'playing]',
#   'builds]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'continues]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'builds,',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'building]',
#   'builds]',
#   'trails',
#   'playing]',
#   'playing]',
#   'swells]',
#   'intensifies]',
#   'playing]'],
#  'playing]': ['[student',
#   '[whistle',
#   '[radio',
#   '[branches',
#   'Wednesday',
#   'Larissa,',
#   '[haunting',
#   '[car',
#   'Oh,',
#   '[both',
#   '[water',
#   '[typewriter',
#   '[indistinct',
#   '[screams]',
#   'On',
#   '[exhales',
#   'So',
#   'He’s',
#   '[Wednesday',
#   'It',
#   'Hey.',
#   '[bestial',
#   '\n\n\n\n\n\n'],
#  '[student': ['laughing]'],
#  'laughing]': ['[heavy', '[locker', '[gasps]'],
#  '[heavy': ['footfalls', 'footfalls'],
#  'footfalls': ['echoing]', 'continue'],
#  'echoing]': ['[girl]', '[school'],
#  '[girl]': ['I’m', 'I’m'],
#  'I’m': ['not',
#   'not',
#   'no',
#   'guessing',
#   'not',
#   'assuming',
#   'gonna',
#   'sure',
#   'not',
#   'told',
#   'not',
#   'Ms.',
#   'not',
#   'done?',
#   'sure',
#   'here',
#   'glad',
#   'all',
#   'going',
#   'Tyler,',
#   'gonna',
#   'failing',
#   'upset!',
#   'taking',
#   'going',
#   'in.',
#   'waiting',
#   'gonna',
#   'not',
#   'going',
#   'not',
#   'just'],
#  'not': ['sure',
#   'about',
#   'interested',
#   'gonna',
#   'you,',
#   'afraid',
#   'a',
#   'helpless,',
#   'above',
#   'done',
#   'wanting',
#   'a',
#   'used',
#   'scary.',
#   'afraid',
#   'have',
#   'be'],
#  'sure': ['whose', 'you', 'you’ll', 'that', 'you’re', 'you'],
#  'whose': ['twisted', 'dreams'],
#  'twisted': ['idea'],
#  'idea': ['it', 'to'],
#  'it': ['was',
#   'was',
#   'runs',
#   'was',
#   'up',
#   'was',
#   'to',
#   'as',
#   'to',
#   'yet.',
#   'so',
#   'was',
#   'looks',
#   'easy.',
#   'instinct.',
#   'was',
#   'was',
#   'begins',
#   'doesn’t',
#   'before.',
#   'when',
#   '40.',
#   'out.',
#   'again.',
#   'as',
#   'worth',
#   'a',
#   'matter',
#   'back',
#   'backwards.',
#   'before',
#   'was',
#   'pains',
#   'here.',
#   'all'],
#  'was': ['to',
#   'the',
#   'going',
#   'a',
#   'the',
#   'born',
#   'founded',
#   'my',
#   'two',
#   'settling',
#   'a',
#   'clearly',
#   'possible',
#   'walking',
#   'about',
#   'my',
#   'friends',
#   'headed',
#   'trying',
#   'sent',
#   'that',
#   'ten.',
#   'surprised.',
#   'the',
#   'six',
#   'snowing',
#   'left',
#   'going',
#   'at',
#   'you?',
#   'a',
#   'a',
#   'my',
#   'your',
#   'mysteriously'],
#  'put': ['hundreds', 'them', 'me'],
#  'hundreds': ['of'],
#  'adolescents': ['in'],
#  'underfunded': ['schools'],
#  'schools': ['run', 'in'],
#  'run': ['by', 'for'],
#  'people': ['whose',
#   'like',
#   'express',
#   'in',
#   'just',
#   'who',
#   'up.',
#   'engaging'],
#  'dreams': ['were', 'of'],
#  'were': ['crushed',
#   'born?',
#   'roommates',
#   'guided',
#   'ten,',
#   'bored,',
#   'harassing',
#   'ambushed.',
#   'gonna',
#   'right,'],
#  'crushed': ['years'],
#  'years': ['ago…', 'in', 'old.', 'ago', 'ago.', 'after'],
#  'ago…': ['but'],
#  'I': ['admire',
#   'want',
#   'don’t',
#   'do',
#   'close',
#   'drift',
#   'softly',
#   'fall',
#   'remember',
#   'promise',
#   'have',
#   'merely',
#   'met',
#   'failed',
#   'never',
#   'was',
#   'bet',
#   'break',
#   'don’t',
#   'suggest',
#   'know,',
#   'heard',
#   'actually',
#   'find',
#   'need',
#   'give',
#   'will',
#   'did.',
#   'got',
#   'will',
#   'shouldn’t',
#   'don’t.',
#   'know',
#   'just',
#   'can…',
#   'devote',
#   'write',
#   'realize',
#   'look',
#   'wanted',
#   'wasn’t',
#   'trust',
#   'hope',
#   'try',
#   'read',
#   'immediately',
#   'leave,',
#   'want',
#   'gonna',
#   'do.',
#   'would',
#   'know',
#   'guarantee',
#   'never',
#   'remember',
#   'was',
#   'never',
#   'think.',
#   'looked',
#   'thought,',
#   'didn’t',
#   'shoulda',
#   'would',
#   'returned',
#   'was',
#   'guess.',
#   'don’t',
#   'had',
#   'got',
#   'just',
#   'knew',
#   'could',
#   'wouldn’t',
#   'see',
#   'lock',
#   'have',
#   'wish',
#   'read',
#   'hope',
#   'think',
#   'see',
#   'did',
#   'know',
#   'want.',
#   'understand',
#   'seek',
#   'sent',
#   'was',
#   'found',
#   'don’t',
#   'use',
#   'can',
#   'need',
#   'know',
#   'need',
#   'don’t',
#   'refuse',
#   'built',
#   'was',
#   'wanted',
#   'never',
#   'didn’t',
#   'drive',
#   'don’t',
#   'can’t',
#   'swear,',
#   'wasn’t',
#   'could',
#   'was',
#   'have',
#   'hope',
#   'don’t',
#   'had',
#   'can’t.',
#   'got.',
#   'had',
#   'may',
#   'could',
#   'was',
#   'took',
#   'buried',
#   'cried',
#   'vowed',
#   'know',
#   'figured',
#   'can',
#   'wish',
#   'was',
#   'didn’t',
#   'trust',
#   'can',
#   'don’t',
#   'want',
#   'thought.',
#   'need',
#   'do.',
#   'love',
#   'wanted',
#   'think',
#   'prefer',
#   'don’t',
#   'think',
#   'have',
#   'narrowly',
#   'could',
#   'think',
#   'made',
#   'need',
#   'haven’t',
#   'develop',
#   'love',
#   'go',
#   'wouldn’t',
#   'suggested',
#   'did'],
#  'admire': ['the'],
#  'sadism.': ['[heavy'],
#  'continue': ['echoing]', 'grunting]', 'baying]'],
#  '[school': ['bell', 'bell'],
#  'bell': ['rings]', 'rings]'],
#  'rings]': ['[jocks', 'You', '[ominous'],
#  '[jocks': ['guffawing]', 'jeering]', 'laughing]', 'chuckle]', 'clamor]'],
#  'guffawing]': ['[gags,'],
#  '[gags,': ['whimpers]'],
#  'whimpers]': ['[thud]'],
#  '[thud]': ['I'],
#  'want': ['names.', 'to', 'me', 'to', 'to', 'to', 'to', 'you', 'you', 'to'],
#  'names.': ['I'],
#  'don’t': ['know',
#   'plan',
#   'you',
#   'have',
#   'believe',
#   'go',
#   'have',
#   'remember',
#   'know,',
#   'we',
#   'travel',
#   'have',
#   'get',
#   'really',
#   'fix',
#   'want',
#   'travel',
#   'have',
#   'know'],
#  'know': ['who',
#   'I',
#   'they’re',
#   'these',
#   'it?',
#   'how',
#   'how',
#   'the',
#   'the',
#   'what',
#   'their',
#   'Nevermore',
#   'they',
#   'I’m',
#   'the'],
#  'they': ['were,',
#   'rip',
#   'broke',
#   'let',
#   'drop',
#   'spent',
#   'thought',
#   'underestimate',
#   'changed',
#   'were',
#   'come'],
#  'were,': ['honest.'],
#  'honest.': ['It'],
#  'It': ['happened',
#   'matches',
#   'looks',
#   'was',
#   'can',
#   'can',
#   'takes',
#   'was',
#   'was'],
#  'happened': ['so', 'the', 'to', 'today,', 'to'],
#  'so': ['fast.',
#   'many',
#   'we’ll',
#   'far',
#   'please',
#   'desperately',
#   'all',
#   'either'],
#  'fast.': ['Pugsley,'],
#  'Pugsley,': ['emotion', 'you’re'],
#  'emotion': ['equals'],
#  'equals': ['weakness.'],
#  'weakness.': ['Pull'],
#  'Pull': ['yourself', 'out'],
#  'yourself': ['together.'],
#  'together.': ['[whimpers]'],
#  '[whimpers]': ['Now.'],
#  'Now.': ['[eerie'],
#  '[eerie': ['whooshing]', 'whooshing]'],
#  'whooshing]': ['[jocks', 'Although', '[cell', '[Rowan]'],
#  'jeering]': ['[jock]'],
#  '[jock]': ['You'],
#  'You': ['scared,',
#   'okay?',
#   'guys',
#   'sure',
#   'always',
#   'look',
#   'can',
#   'catch',
#   'better',
#   'should',
#   'have',
#   'are',
#   'know',
#   'don’t',
#   'must',
#   'probably',
#   'pledge',
#   'know',
#   'can’t',
#   'goddamn',
#   'go',
#   'have',
#   'have',
#   'really',
#   'just',
#   'should',
#   'see',
#   'okay?',
#   'want',
#   'insisted',
#   'don’t'],
#  'scared,': ['kid?'],
#  'kid?': ['Scared?'],
#  'Scared?': ['[jocks'],
#  '[locker': ['slams]'],
#  'slams]': ['[school', 'I'],
#  'okay?': ['[girl]', 'You', 'You', 'I’m'],
#  'about': ['to',
#   'Wednesday’s,',
#   'your',
#   'you.',
#   'me,',
#   'the',
#   'going',
#   'Nevermore,',
#   'bees.',
#   'the…',
#   'two',
#   'me.',
#   'that?',
#   'it.',
#   'a',
#   'her?',
#   'trains?',
#   'I',
#   'me…',
#   'my',
#   'this',
#   'it',
#   'to'],
#  'confess': ['to'],
#  'my': ['brother',
#   'brother',
#   'eyes',
#   'parents',
#   'little',
#   'favorite',
#   'little',
#   'memory.',
#   'bones.',
#   'parents’',
#   'mother',
#   'victims,',
#   'menagerie',
#   'new',
#   'little',
#   'love.',
#   'room?',
#   'writing',
#   'novel.',
#   'voice.',
#   'truth.',
#   'followers',
#   'name',
#   'conservatory.',
#   'girls.',
#   'favorite',
#   'money.',
#   'undying',
#   'godmother’s',
#   'highly',
#   'strings',
#   'personal',
#   'writing',
#   'coffee',
#   'dolls',
#   'appreciation,',
#   'eye',
#   'father?',
#   'family',
#   'pet',
#   'little',
#   'dad',
#   'train',
#   'destiny',
#   'little',
#   'father',
#   'mind.'],
#  'brother': ['that', 'is'],
#  'that': ['I’ve',
#   'I’m',
#   'finally',
#   'have',
#   'she',
#   'case,',
#   'you',
#   'girl,',
#   'kid',
#   'tree',
#   'off.',
#   'Wednesday',
#   'splash',
#   'way',
#   'effect',
#   'gargoyle',
#   'thing',
#   'from',
#   'this',
#   'must',
#   'you',
#   'I',
#   'of',
#   'the',
#   'on',
#   'quad',
#   'could',
#   'oversized',
#   'too?',
#   'normie?',
#   'I',
#   'sad,',
#   'was',
#   'picture',
#   'my',
#   'I',
#   'can',
#   'happens',
#   'is',
#   'could'],
#  'I’ve': ['recently',
#   'spoken',
#   'assigned',
#   'alerted',
#   'read',
#   'answered',
#   'always',
#   'seen',
#   'never',
#   'been',
#   'got',
#   'been'],
#  'recently': ['been'],
#  'been': ['plagued',
#   'looking',
#   'swirling',
#   'here',
#   'slipping',
#   'smothering',
#   'open',
#   'with',
#   'to',
#   'hunted,'],
#  'plagued': ['by'],
#  'visions.': ['They', 'It’s'],
#  'They': ['come', 'haven’t', 'respond', 'were', 'wondered', 'prefer'],
#  'come': ['on', 'to', 'to', 'on.', 'back!', 'across'],
#  'on': ['without',
#   'giving',
#   'your',
#   'Friday',
#   'the',
#   'staying',
#   'Nevermore’s',
#   'quick.',
#   'that',
#   'your',
#   'the',
#   'people,',
#   'the',
#   'me,',
#   'the',
#   'running',
#   'trust',
#   'the',
#   'a',
#   'a',
#   'in',
#   'you.',
#   'Sheriff',
#   'Wednesday…',
#   'their'],
#  'without': ['warning,', 'the', 'me.'],
#  'warning,': ['and'],
#  'feel': ['like', 'any', 'about', 'better.'],
#  'like': ['electroshock',
#   'no',
#   'you',
#   'us.',
#   'mosquitos',
#   'a',
#   'to',
#   'you’re',
#   'Dalton',
#   'religious',
#   'an',
#   'your'],
#  'electroshock': ['therapy,'],
#  'therapy,': ['but'],
#  'satisfying': ['afterburn.'],
#  'afterburn.': ['Leave'],
#  'Leave': ['this'],
#  'this': ['to',
#   'place',
#   'is',
#   'is',
#   'uniform',
#   'educational',
#   'toe-curling',
#   'wasn’t',
#   'a',
#   'one.',
#   'or',
#   'all',
#   'teenage',
#   'feeble',
#   'is',
#   'journey',
#   'angle?',
#   'place.',
#   'is',
#   'weekend.',
#   'hellhole',
#   'pathetic',
#   'girl',
#   'monster-in-the-woods',
#   'school.'],
#  'me.': ['Wednesday?',
#   '♪',
#   'I',
#   'They’ve',
#   'I',
#   'This',
#   'It',
#   'Last',
#   'Oh,',
#   'They’re',
#   '♪',
#   'Boo!',
#   'He',
#   'Come',
#   'Still',
#   'Most'],
#  'Wednesday?': ['What', 'Is'],
#  'What': ['are',
#   'I',
#   'our',
#   'happens',
#   'plan?',
#   'do',
#   'the',
#   'happened?',
#   'happened',
#   'you’re',
#   'about',
#   'happened?',
#   'did',
#   'happens',
#   'does',
#   'do',
#   'are'],
#  'are': ['you',
#   'making',
#   'different.',
#   'many',
#   'Fangs,',
#   'the',
#   'Furs,',
#   'sirens?',
#   'a',
#   'over',
#   'so',
#   'connected',
#   'clearly',
#   'two',
#   'a',
#   'a',
#   'short-sighted,',
#   'in',
#   'you',
#   'late',
#   'you',
#   'you',
#   'you',
#   'you',
#   'marked',
#   'tasked'],
#  'you': ['gonna',
#   '♪',
#   'said',
#   'intend',
#   'will',
#   'will',
#   'expelled.',
#   'want',
#   'and',
#   'were',
#   'we',
#   'graduated',
#   'hear',
#   'to',
#   'feeling',
#   'a',
#   'can',
#   'killed',
#   'off.',
#   'a',
#   'pick',
#   'in',
#   'boys',
#   'two',
#   'have',
#   'darken',
#   'underestimate',
#   'will',
#   'get',
#   'a',
#   'don’t',
#   'for',
#   'next',
#   'want',
#   'do',
#   'did',
#   'mean,',
#   'when',
#   'arrived.',
#   'the',
#   'know',
#   'whined',
#   'wouldn’t',
#   'must',
#   'to',
#   'bleed',
#   'feel.',
#   'don’t.',
#   'don’t',
#   'probably',
#   'tackled',
#   'were',
#   'to',
#   'haven’t',
#   'feel',
#   'hit',
#   'think',
#   'to',
#   'poor,',
#   'have',
#   'in',
#   'go',
#   'are.',
#   'luck.',
#   'feel',
#   'assaulted',
#   'understand',
#   'new',
#   'build',
#   'want.',
#   'tell',
#   'take',
#   'mind',
#   'out?',
#   'make',
#   'read',
#   'going',
#   'what,',
#   'to',
#   'dressed',
#   'ever',
#   'learn',
#   'help',
#   'tell',
#   'get',
#   'wolfing',
#   'believe',
#   'know.',
#   'kidding',
#   'crying?',
#   'ever',
#   'above',
#   'like',
#   'still',
#   'in',
#   'sure',
#   'can',
#   'talking',
#   'home',
#   'get',
#   'mind',
#   'leave,',
#   'to',
#   'want?',
#   'following',
#   'doing?',
#   'were',
#   'rather',
#   'so!',
#   'manage',
#   'really',
#   'hear'],
#  'gonna': ['do?',
#   'believe',
#   'miss',
#   'get',
#   'give',
#   'keep',
#   'be',
#   'be',
#   'make'],
#  'do?': ['What'],
#  'do': ['best.', '♪', 'you', 'you', 'to', 'this', 'in', 'it', 'you', 'you'],
#  'best.': ['[“Non,'],
#  '[“Non,': ['Je'],
#  'Je': ['Ne'],
#  'Ne': ['Regrette'],
#  'Regrette': ['Rien”'],
#  'Rien”': ['by'],
#  'Édith': ['Piaf'],
#  'Piaf': ['playing]'],
#  '[whistle': ['blows]', 'blowing'],
#  'blows]': ['♪'],
#  '♪': ['Non,',
#   '[jock',
#   'Non,',
#   '[jocks',
#   'Non,',
#   '♪',
#   'Car',
#   '[whistle',
#   'Ça',
#   '[shrieks]',
#   'I',
#   '♪',
#   'Then',
#   '[passenger',
#   'Into',
#   '♪',
#   'I',
#   '[both]',
#   'A',
#   '♪',
#   'Like',
#   '♪',
#   'Then',
#   '♪',
#   'My',
#   '♪',
#   'I',
#   '[bird',
#   'That',
#   '[feeble',
#   'Ay',
#   '♪',
#   'Llorona,',
#   '[bed',
#   'Ay',
#   '♪',
#   'Llorona,',
#   'I',
#   '…que',
#   'Our'],
#  'Non,': ['rien', 'rien', 'je'],
#  'rien': ['de', 'de', '♪', '♪'],
#  'de': ['rien…', 'rien', 'mí,', 'mí,', 'mí…'],
#  'rien…': ['♪'],
#  '[jock': ['1]'],
#  '1]': ['Yo,', 'What’s'],
#  'Yo,': ['Dalton,', 'Enid!'],
#  'Dalton,': ['look.'],
#  'look.': ['Pigsley’s'],
#  'Pigsley’s': ['sister.'],
#  'sister.': ['Hey,'],
#  'Hey,': ['freak.', 'boys,', 'before'],
#  'freak.': ['This'],
#  'This': ['is',
#   'was',
#   'is',
#   'is',
#   'kitty’s',
#   'is',
#   'is',
#   'little',
#   'one',
#   'isn’t',
#   'is',
#   'season',
#   'story’s',
#   'ends'],
#  'closed': ['practice.'],
#  'practice.': ['[jocks'],
#  'chuckle]': ['The', 'What'],
#  'The': ['only',
#   'trail',
#   'court',
#   'school',
#   'whole',
#   'black',
#   'locals',
#   'score',
#   'last',
#   'way',
#   'relationship',
#   'feeling',
#   'gargoyle,'],
#  'only': ['person'],
#  'person': ['who'],
#  'torture': ['my'],
#  'clamor]': ['♪'],
#  'je': ['ne'],
#  'ne': ['regrette'],
#  'regrette': ['rien'],
#  'Car': ['ma'],
#  'ma': ['vie,'],
#  'vie,': ['car'],
#  'car': ['mes'],
#  'mes': ['joies'],
#  'joies': ['♪'],
#  'blowing': ['frantically]'],
#  'frantically]': ['♪', 'Mother'],
#  'Ça': ['commence'],
#  'commence': ['avec'],
#  'avec': ['toi'],
#  'toi': ['♪'],
#  '[shrieks]': ['[elegant'],
#  '[elegant': ['music'],
#  'swells,': ['fades', 'finishes]'],
#  'fades': ['away]', 'away]'],
#  'away]': ['[jauntily', '[lock'],
#  'theme': ['music', 'music', 'park'],
#  '[radio': ['squawks,'],
#  'squawks,': ['playing'],
#  'playing': ['“In', 'peppy', '“Paint'],
#  '“In': ['Dreams”'],
#  'Dreams”': ['by'],
#  'Roy': ['Orbison]'],
#  'Orbison]': ['♪'],
#  'close': ['my'],
#  'eyes': ['♪'],
#  'Then': ['I', 'I', 'I', 'you', 'you’re'],
#  'drift': ['away'],
#  'away': ['♪', 'end', 'from'],
#  '[passenger': ['singing'],
#  'singing': ['along]'],
#  'along]': ['♪'],
#  'Into': ['the'],
#  'magic': ['night'],
#  'night': ['♪'],
#  'softly': ['say'],
#  'say': ['♪', 'is', 'hurtful', 'thank', 'I', 'I'],
#  '[both]': ['♪'],
#  'A': ['silent', 'sanctuary'],
#  'silent': ['prayer'],
#  'prayer': ['♪'],
#  'Like': ['dreamers', 'me!', 'a'],
#  'dreamers': ['do'],
#  'fall': ['asleep', 'in', 'far'],
#  'asleep': ['to'],
#  'dream': ['♪'],
#  'My': ['dreams',
#   'counselor',
#   'vlog',
#   'mother',
#   'parents',
#   'dad',
#   'uncle',
#   'mom',
#   'life',
#   'mother',
#   'mother'],
#  'remember': ['♪', 'I', 'me.'],
#  '[bird': ['chirps]', 'caws]'],
#  'chirps]': ['[birds'],
#  '[birds': ['thudding'],
#  'thudding': ['in'],
#  'time': ['to', 'getting', 'we', 'we', 'to', 'to'],
#  'music]': ['♪'],
#  'That': ['you', 'boy’s', 'school', 'bunch', 'means', 'first', 'they', 'man'],
#  'said': ['goodbye…', 'you', 'in', 'it'],
#  'goodbye…': ['♪'],
#  '[feeble': ['tweeting]'],
#  'tweeting]': ['[both'],
#  '[both': ['moaning]', 'grunting]', 'continue'],
#  'moaning]': ['[woman]'],
#  '[woman]': ['Mmm.', 'Hmm.'],
#  'Mmm.': ['[man'],
#  '[man': ['sighs]'],
#  'sighs]': ['Darling,'],
#  'Darling,': ['how', 'we'],
#  'how': ['long', 'people', 'you', 'much', 'vain', 'about', 'to', 'was'],
#  'long': ['do', 'history'],
#  'intend': ['on'],
#  'giving': ['us', 'your'],
#  'us': ['the', 'going', 'will', 'darling,', 'everything.'],
#  'cold': ['shoulder?'],
#  'shoulder?': ['Lurch,'],
#  'Lurch,': ['please', 'the'],
#  'please': ['remind', 'take', 'don’t'],
#  'remind': ['my'],
#  'no': ['longer',
#   'interest',
#   'other',
#   'loud',
#   'boys,',
#   'smothering',
#   'se',
#   'remorse',
#   'real',
#   'taxis',
#   'idea,',
#   'prospect',
#   'charge.'],
#  'longer': ['speaking'],
#  'speaking': ['to'],
#  'them.': ['[Lurch', 'Hmm.', '[door', '[Weems]'],
#  '[Lurch': ['grunts]'],
#  'grunts]': ['[woman]', 'Pugsley,', '[fencer', 'Coach,', '[bone'],
#  'Hmm.': ['I', '[man]', 'Did', 'The', 'Ironic,'],
#  'promise': ['you,'],
#  'you,': ['my', 'my', 'too,', 'Mother.', 'the'],
#  'little': ['viper,',
#   'storm',
#   'pale.',
#   'deathtrap.',
#   'something.',
#   'scorpion',
#   'pictures.',
#   'welcome',
#   'thing',
#   'black',
#   'black'],
#  'viper,': ['you'],
#  'will': ['love', 'be', 'escape', 'never', 'never', 'get', 'destroy', 'not'],
#  'love': ['Nevermore.', 'Nevermore,', 'you.\xa0I', 'you.', 'it', 'you'],
#  'Won’t': ['she,'],
#  'she,': ['Tish?'],
#  'Tish?': ['Of', 'Yes.'],
#  'Of': ['course.', 'course.', 'course', 'course.'],
#  'course.': ['It’s', 'It’s', 'It’s'],
#  'It’s': ['the',
#   'a',
#   'where',
#   'so…',
#   'all',
#   'a',
#   'a',
#   'made',
#   'a',
#   'my',
#   'what',
#   'how',
#   'named',
#   'a',
#   'your',
#   'more',
#   'an',
#   'four',
#   'a',
#   'the',
#   'half',
#   'one',
#   'all',
#   'your',
#   'always'],
#  'perfect': ['school', 'school', 'grades', 'sense.'],
#  'Why?': ['Because', '[clicks', '‘Cause'],
#  'Because': ['it', 'I', 'I', 'I’m'],
#  'you?': ['I', '[flatly]', 'Didn’t', 'Yeah.'],
#  'have': ['no',
#   'looked',
#   'worked',
#   'literally',
#   'of',
#   'nowhere',
#   'a',
#   'one.',
#   'a',
#   'a',
#   'an',
#   'rather',
#   'two',
#   'a',
#   'is',
#   'no',
#   'a',
#   'a',
#   'one',
#   'no',
#   'a',
#   'you',
#   'this.',
#   'time',
#   'to',
#   'Ted'],
#  'interest': ['in'],
#  'following': ['in', 'emojis', 'me?'],
#  'your': ['footsteps.',
#   'mother.',
#   'record?',
#   'throat',
#   'mother',
#   'sanity',
#   'family’s',
#   'mother’s',
#   'new',
#   'favorite',
#   'old',
#   'parents',
#   'obviously',
#   'new',
#   'back.',
#   'own',
#   'spirits',
#   'age',
#   'mother.',
#   'side.',
#   'vlog',
#   'stories',
#   'final',
#   'dorm',
#   'personal',
#   'application,',
#   'claws',
#   'decision,',
#   'grandmother,',
#   'godmother',
#   'favorite',
#   'way',
#   'nails',
#   'smooth,',
#   'undying',
#   'students',
#   'pay',
#   'history,',
#   'school',
#   'views',
#   'brother,',
#   'response',
#   'actions.',
#   'questions.',
#   'emotions.',
#   'plans',
#   'work',
#   'psych',
#   'machine?',
#   'coffee',
#   'name,',
#   'father?',
#   'single',
#   'computer.',
#   'pet?',
#   'while.',
#   'dad’s',
#   'first',
#   'secret?',
#   'side'],
#  'footsteps.': ['Becoming'],
#  'Becoming': ['captain'],
#  'captain': ['of'],
#  'fencing': ['team,'],
#  'team,': ['Queen'],
#  'Queen': ['of', 'Bee.'],
#  'Dark': ['Prom,'],
#  'Prom,': ['President'],
#  'President': ['of'],
#  'Séance': ['Society.'],
#  'Society.': ['I'],
#  'merely': ['meant'],
#  'meant': ['that'],
#  'finally': ['you', 'got', 'fit'],
#  'be': ['among',
#   'any',
#   'a',
#   'a',
#   'alone.',
#   'swarming',
#   'appreciated.',
#   'coherent.',
#   'the',
#   'the',
#   'an',
#   'rescued.',
#   'here',
#   'endured,',
#   'killed.',
#   'a',
#   'bought,',
#   'officially',
#   'kicked',
#   'a',
#   'here.',
#   'taking',
#   'trickier',
#   'a',
#   'published.'],
#  'among': ['peers'],
#  'peers': ['who'],
#  'understand': ['you.', 'yourself.', 'you’ve'],
#  'you.': ['Maybe',
#   'You',
#   'When',
#   'Okey-dokey.',
#   'I',
#   'And',
#   '[melancholic',
#   'Okay.',
#   'At',
#   '[fireworks',
#   '[grunts]',
#   'The',
#   'You'],
#  'Maybe': ['you’ll', 'if'],
#  'you’ll': ['even', 'grow', 'be'],
#  'even': ['make', 'from', 'more'],
#  'make': ['some', 'sure', 'a', 'my', 'it', 'it', 'it'],
#  'some': ['friends.', 'wolves', 'dead', 'picture?'],
#  'friends.': ['Nevermore', 'You’re'],
#  'other': ['boarding', 'two'],
#  'boarding': ['school.'],
#  'magical': ['place.'],
#  'place.': ['It’s', 'This', 'Not'],
#  'where': ['I', 'we'],
#  'met': ['your', 'a'],
#  'mother.': ['And', 'Lurch,'],
#  'And': ['we', 'you', 'that', 'we', 'it', 'chauffeuring', 'no'],
#  'we': ['fell',
#   'aren’t',
#   'were',
#   'go',
#   'clear?',
#   'doing',
#   'met,',
#   'met?',
#   'were',
#   'were',
#   'both',
#   'can',
#   'can',
#   'can',
#   'dig',
#   'have',
#   'were',
#   'need'],
#  'fell': ['in'],
#  'love.': ['[yearning', 'Our', 'Your'],
#  '[yearning': ['sigh]'],
#  'sigh]': ['You'],
#  'guys': ['are'],
#  'making': ['me', 'any', 'enemies', 'a'],
#  'me': ['nauseous.',
#   'here.',
#   'into',
#   'give',
#   'the',
#   'again.',
#   'to',
#   'with',
#   'I’d',
#   'a',
#   'out',
#   'from',
#   'about',
#   'about',
#   'Gomez',
#   'down',
#   'watch…',
#   'how',
#   'escape?',
#   'to',
#   'with',
#   'behind',
#   'coming',
#   'because',
#   'about',
#   'down.',
#   'to',
#   'screaming'],
#  'nauseous.': ['Not'],
#  'Not': ['in', 'a', 'just'],
#  'good': ['way.', 'deed', 'luck', 'chance'],
#  'way.': ['Darling,', '[ominous', 'I’m', 'Why?', 'I'],
#  'aren’t': ['the', 'worried', 'you'],
#  'ones': ['who'],
#  'got': ['you', 'you', 'claws,', 'that', 'stuck', 'their', 'some', 'it'],
#  'boy’s': ['family'],
#  'family': ['was', 'members', 'mysteries.', 'pack'],
#  'going': ['to',
#   'to',
#   'to',
#   'into',
#   'to',
#   'to',
#   'to',
#   'anyway?',
#   'on',
#   'to',
#   'to',
#   'with',
#   'to'],
#  'file': ['attempted', 'from'],
#  'attempted': ['murder', 'murder.'],
#  'murder': ['charges.'],
#  'charges.': ['How'],
#  'How': ['would', 'did', 'did', 'can', 'the', 'would', 'do'],
#  'would': ['that', 'know', 'be', 'like', 'have', 'you', 'be', 'have', 'you'],
#  'looked': ['on', 'up'],
#  'record?': ['Terrible.'],
#  'Terrible.': ['Everyone'],
#  'Everyone': ['would'],
#  'failed': ['to'],
#  'get': ['the',
#   'out',
#   'you',
#   'pretty',
#   'on\xa0Insta,',
#   'in',
#   'real',
#   'off',
#   'that',
#   'out',
#   'any'],
#  'job': ['done.'],
#  'done.': ['Hmm.'],
#  '[man]': ['Just'],
#  'Just': ['over', 'take', 'preparing'],
#  'here': ['is', 'for', 'things', 'for', 'to', 'for', 'until', 'to'],
#  'fine.': ['Thanks.'],
#  'Thanks.': ['You', '[bird', 'I'],
#  'out': ['here?',
#   'into',
#   'of',
#   'their',
#   'of',
#   'proves',
#   'of',
#   'of',
#   'in',
#   'of',
#   'of',
#   'pizzicato',
#   'the',
#   'of',
#   'for',
#   'of',
#   'there,',
#   'your'],
#  'here?': ['The', 'They', 'Incredible'],
#  'trail': ['might'],
#  'might': ['look', 'have', 'be'],
#  'look': ['pretty,', 'a', 'at'],
#  'pretty,': ['but'],
#  'runs': ['right'],
#  'right': ['past', 'now.', 'flower'],
#  'past': ['Nevermore.'],
#  'outcasts?': ['Huh.'],
#  'Huh.': ['That’s'],
#  'That’s': ['a', 'when', 'easy.', 'why', 'on', 'Thing.', 'you.'],
#  'polite': ['way'],
#  'way': ['of', 'too', 'before.', 'out.', 'I', 'out,', 'to'],
#  'putting': ['it.'],
#  'it.': ['I', 'Please', 'Everything', '[tense', '[arcane'],
#  'never': ['had',
#   'survive',
#   'hear',
#   'fall',
#   'thought',
#   'felt',
#   'bring',
#   'met',
#   'found',
#   'do'],
#  'had': ['a', 'a', 'a', 'the', 'cheated', 'a', 'to', 'an', 'to'],
#  'problem': ['with', 'here.'],
#  'counselor': ['at'],
#  'summer': ['camp'],
#  'camp': ['was'],
#  'werewolf.': ['Great'],
#  'Great': ['guy.', 'talk.'],
#  'guy.': ['Yeah,'],
#  'Yeah,': ['they’re', 'it…', 'I…', 'she'],
#  'they’re': ['just', 'going'],
#  'just': ['like',
#   'can’t',
#   'say',
#   'let',
#   'say',
#   'figured',
#   'something',
#   'because',
#   'need',
#   'kinda…',
#   'enjoying'],
#  'me,': ['until', 'Mother.', 'at', 'didn’t', 'freak…', 'I’ve'],
#  'until': ['they', 'I', 'I’m'],
#  'rip': ['your'],
#  'throat': ['out.'],
#  'out.': ['[chuckles', 'I', 'Either', 'Who’s', 'But'],
#  '[chuckles': ['wryly]'],
#  'wryly]': ['Thanks.'],
#  'caws]': ['[low,'],
#  '[low,': ['menacing', 'menacing'],
#  'menacing': ['music', 'music'],
#  '[branches': ['snapping]'],
#  'snapping]': ['[ragged'],
#  '[ragged': ['breathing]'],
#  'breathing]': ['[creature'],
#  '[creature': ['snarls]', 'snarls,'],
#  'snarls]': ['[panicked'],
#  '[panicked': ['screaming]'],
#  'screaming]': ['[gate', '[Wednesday]'],
#  '[gate': ['hinges'],
#  'hinges': ['creak]'],
#  'creak]': ['[ominous'],
#  '[ominous': ['music', 'music', 'music', 'chanting]', 'music', 'whooshing]'],
#  'builds]': ['[sighs]', '[cello', '[tense'],
#  '[sighs]': ['At', 'You'],
#  'At': ['least', 'least'],
#  'least': ['it’s', 'spell', 'I’ll', 'one'],
#  'it’s': ['turning', 'a', 'concealed.', 'a', 'the'],
#  'turning': ['into'],
#  'into': ['a', 'hives', 'a', 'the', 'that?'],
#  'beautiful': ['day.'],
#  'day.': ['[bells', '[desk'],
#  '[bells': ['tolling]'],
#  'tolling]': ['[thunder'],
#  '[thunder': ['rumbling]', 'booms]'],
#  'rumbling]': ['[playfully', '[sweeping'],
#  '[playfully': ['gloomy'],
#  'gloomy': ['music'],
#  'certainly': ['a', 'had'],
#  'unique': ['name.', 'perspective'],
#  'name.': ['I’m'],
#  'guessing': ['it'],
#  'day': ['you', 'to', 'and'],
#  'born?': ['I'],
#  'born': ['on'],
#  'Friday': ['the'],
#  '13th.': ['Her'],
#  'name': ['comes', 'correctly.'],
#  'comes': ['from'],
#  'line': ['from'],
#  'favorite': ['nursery', 'marginalized', 'unsolved', 'hand'],
#  'nursery': ['rhyme,'],
#  'rhyme,': ['“Wednesday’s'],
#  '“Wednesday’s': ['child'],
#  'child': ['is'],
#  'full': ['of', 'of', 'story.'],
#  'woe.”': ['You'],
#  'always': ['had', 'looks', 'been', 'the'],
#  'perspective': ['on'],
#  'world,': ['Morticia.', 'personal'],
#  'Morticia.': ['Hmm.'],
#  'Did': ['your', 'you', 'you', 'you', 'you'],
#  'mother': ['tell', 'smirking', 'promised', 'drew', 'said'],
#  'tell': ['you', 'the', 'me', 'me,', 'me', 'from', 'us', 'us'],
#  'roommates': ['back'],
#  'day?': ['And'],
#  'graduated': ['with'],
#  'sanity': ['intact?'],
#  'intact?': ['Impressive.'],
#  'Impressive.': ['You’ve'],
#  'You’ve': ['certainly'],
#  'very': ['interesting'],
#  'interesting': ['educational'],
#  'educational': ['journey.', 'penitentiary,'],
#  'journey.': ['Eight', 'Nail'],
#  'Eight': ['schools'],
#  'five': ['years.', 'years'],
#  'years.': ['They'],
#  'haven’t': ['built', 'changed.', 'lost'],
#  'built': ['one', 'it'],
#  'one': ['strong',
#   'who',
#   'source',
#   'of',
#   'of',
#   'fun',
#   'that',
#   'slipped',
#   'of',
#   'of',
#   'who’s'],
#  'strong': ['enough'],
#  'enough': ['to'],
#  'hold': ['me.'],
#  'bet': ['this'],
#  'place': ['won’t', 'that'],
#  'won’t': ['be', 'be'],
#  'any': ['different.',
#   'excuse',
#   'more',
#   'waves,',
#   'outcast',
#   'better,',
#   'better'],
#  'different.': ['What', 'Let'],
#  'our': ['daughter',
#   'resident',
#   'connection.',
#   'room',
#   'last',
#   'uncomfortable',
#   'booth.'],
#  'daughter': ['is', 'all'],
#  'trying': ['to', 'to', 'to'],
#  'greatly': ['appreciates'],
#  'appreciates': ['the'],
#  'opportunity.': ['Nevermore'],
#  'doesn’t': ['usually', 'need', 'help', 'fall'],
#  'usually': ['accept'],
#  'accept': ['students'],
#  'students': ['mid-term,', 'swear', 'around'],
#  'mid-term,': ['but'],
#  'given': ['Wednesday’s', 'you'],
#  'grades': ['and'],
#  'family’s': ['long'],
#  'history': ['with'],
#  'school,': ['I’ve', 'and', 'but', 'and'],
#  'spoken': ['with'],
#  'board': ['and'],
#  'we’ve': ['made', 'special'],
#  'made': ['an', 'of', 'me', 'it'],
#  'exception.': ['[quirky'],
#  '[quirky': ['music'],
#  'Larissa,': ['what'],
#  'what': ['about',
#   'my',
#   'a',
#   'kind',
#   'was',
#   'happened',
#   'happened',
#   'happened'],
#  'Wednesday’s,': ['um…'],
#  'um…': ['therapy'],
#  'sessions?': ['The'],
#  'court': ['ordered'],
#  'ordered': ['them.', 'you'],
#  'relationship': ['with', 'based', 'I'],
#  'therapist': ['in'],
#  'Jericho.': ['She', 'Try'],
#  'can': ['meet',
#   'save',
#   'clear',
#   'visit',
#   'forge',
#   'discuss',
#   'teach',
#   'also',
#   'do',
#   'you',
#   'make',
#   'trust',
#   'handle',
#   'lose',
#   'prove'],
#  'twice': ['a'],
#  'week.': ['Did', 'All'],
#  'hear': ['that,', 'from', 'that.', 'me'],
#  'that,': ['my', 'Sheriff.'],
#  'storm': ['cloud?'],
#  'cloud?': ['You’re'],
#  'You’re': ['in',
#   'not',
#   'in',
#   'Wednesday,',
#   'an',
#   'going',
#   'not.',
#   'not',
#   'just',
#   'the',
#   'really'],
#  'excellent': ['hands.'],
#  'hands.': ['We’ll'],
#  'We’ll': ['see'],
#  'see': ['if', 'if', 'you', 'it,', 'the', 'the', 'that', 'me'],
#  'if': ['she', 'you', 'you', 'you', 'I', 'I’m', 'she'],
#  'survives': ['the'],
#  'first': ['session.', 'week', 'point', 'blood.', 'order', 'day', 'week?'],
#  'session.': ['I’ve', '[Wednesday]'],
#  'assigned': ['you'],
#  'mother’s': ['old'],
#  'old': ['dorm.', 'school,', 'Nevermore', 'saying,'],
#  'dorm.': ['Ophelia'],
#  'Ophelia': ['Hall.', 'Hall.'],
#  'Hall.': ['[gasps,', 'Not'],
#  '[gasps,': ['chuckles'],
#  'chuckles': ['excitedly]'],
#  'excitedly]': ['[Wednesday]', 'Howdy,'],
#  '[Wednesday]': ['Refresh',
#   'I’m',
#   'My',
#   'Let’s',
#   'This',
#   'Since',
#   'You',
#   'This'],
#  'Refresh': ['my'],
#  'memory.': ['Ophelia’s'],
#  'Ophelia’s': ['the'],
#  'kills': ['herself'],
#  'herself': ['after'],
#  'being': ['driven', 'flame-broiled.'],
#  'driven': ['mad'],
#  'mad': ['by'],
#  'family,': ['correct?'],
#  'correct?': ['Should'],
#  'Should': ['we'],
#  'go': ['meet', 'over', 'making', 'slowly', 'to', 'if', 'to'],
#  'new': ['roommate?', 'roommate.', 'roommate,', 'ways'],
#  'roommate?': ['[Morticia'],
#  '[Morticia': ['gasps]'],
#  'gasps]': ['It’s'],
#  'so…': ['vivid.'],
#  'vivid.': ['[inhales'],
#  '[inhales': ['excitedly]'],
#  'Howdy,': ['roomie.'],
#  'roomie.': ['Wednesday,'],
#  'Wednesday,': ['this', 'but', 'right?', 'one', 'we', 'come'],
#  'Enid': ['Sinclair.', 'has'],
#  'Sinclair.': ['Are'],
#  'Are': ['you', 'we', 'we', 'you', 'you', 'you'],
#  'feeling': ['okay?', 'a', 'is'],
#  'pale.': ['Wednesday'],
#  'looks': ['half-dead.', 'like', 'like'],
#  'half-dead.': ['Oh.'],
#  'Oh.': ['Welcome', 'Uh.', 'Now'],
#  'Welcome': ['to', 'to', 'back.'],
#  'hugger.': ['Got', 'Got'],
#  'Got': ['it.', 'it.'],
#  'Please': ['excuse'],
#  'excuse': ['Wednesday.', 'to'],
#  'Wednesday.': ['She’s', 'Whoa.', '[both', 'A', 'Tell', 'To', 'Wednesday!'],
#  'She’s': ['allergic', 'been'],
#  'allergic': ['to'],
#  'color.': ['[Enid]'],
#  '[Enid]': ['Oh,', 'You', 'Well,'],
#  'Oh,': ['wow.', 'I', 'sorry', 'you', 'you', 'Thing,', 'whoa!'],
#  'wow.': ['What'],
#  'happens': ['to', 'then?', 'here?'],
#  '[flatly]': ['I'],
#  'break': ['out'],
#  'hives': ['and'],
#  'then': ['the', 'use', 'feed', 'you’re'],
#  'flesh': ['peels'],
#  'peels': ['off'],
#  'off': ['my', 'at', 'for', 'with'],
#  'bones.': ['Luckily,'],
#  'Luckily,': ['we’ve', 'I’m'],
#  'special': ['ordered', 'kind'],
#  'uniform.': ['[chuckles]', 'I'],
#  '[chuckles]': ['Enid,', '[door', '[Rowan]', 'I'],
#  'take': ['Wednesday', 'it', 'it', 'a', 'a', 'that?', 'a'],
#  'registrar’s': ['office'],
#  'office': ['to', 'is'],
#  'pick': ['it', 'up', 'up'],
#  'along': ['with', 'the'],
#  'schedule,': ['and'],
#  'give': ['her', 'you', 'you', 'me'],
#  'tour': ['along'],
#  '[haunting': ['choral'],
#  'choral': ['vocalizations]'],
#  'vocalizations]': ['Nevermore', '[stone'],
#  'founded': ['in'],
#  '1791': ['to'],
#  'educate': ['people'],
#  'us.': ['Outcasts,'],
#  'Outcasts,': ['freaks,'],
#  'freaks,': ['monsters,'],
#  'monsters,': ['fill'],
#  'fill': ['in', 'your'],
#  'marginalized': ['group'],
#  'group': ['here.', 'of'],
#  'here.': ['You', 'It’s', 'That’s', 'He', 'I', 'I', '[dramatic'],
#  'save': ['the'],
#  'sanitized': ['sales'],
#  'sales': ['pitch.'],
#  'pitch.': ['I'],
#  'plan': ['on'],
#  'staying': ['here'],
#  'long.': ['Why'],
#  'Why': ['not?', 'don’t', 'don’t', 'are', 'aren’t', 'are', 'are'],
#  'not?': ['This', 'En'],
#  'parents’': ['idea.'],
#  'idea.': ['Oh'],
#  'Oh': ['look,', 'yeah,'],
#  'look,': ['there’s'],
#  'there’s': ['my', 'a', 'a', 'a'],
#  'smirking': ['at'],
#  'They’ve': ['been'],
#  'looking': ['for'],
#  'send': ['me'],
#  'all': ['a',
#   'family',
#   'day.',
#   'your',
#   'right.',
#   'we',
#   'I',
#   'die',
#   'things',
#   'up.',
#   'episodes',
#   'costs,',
#   'those'],
#  'part': ['of', 'of'],
#  'their': ['nefarious,',
#   'doorstep.',
#   'feelings.',
#   'sleep.',
#   'stingers,',
#   'twenties',
#   'lives',
#   'hands',
#   'place.',
#   'way'],
#  'nefarious,': ['yet'],
#  'yet': ['completely'],
#  'completely': ['obvious'],
#  'obvious': ['plan.'],
#  'plan.': ['What', 'And'],
#  'plan?': ['To'],
#  'To': ['turn', 'show'],
#  'turn': ['me'],
#  'version': ['of'],
#  'themselves.': ['In'],
#  'In': ['that', 'her'],
#  'case,': ['perhaps'],
#  'perhaps': ['you'],
#  'clear': ['something'],
#  'something': ['up.', 'wrong', 'that', 'that'],
#  'up.': ['Rumor’s', '[cries', 'I'],
#  'Rumor’s': ['been'],
#  'swirling': ['around'],
#  'around': ['that', 'here.', 'is', 'four'],
#  'kid': ['at', 'she', 'who'],
#  'pulled': ['strings'],
#  'strings': ['to', 'even'],
#  'off.': ['Actually,', 'This', 'Stay'],
#  'Actually,': ['it'],
#  'two': ['kids,', 'months,', 'attacks', 'D’s', 'feet', 'options.'],
#  'kids,': ['but'],
#  'who’s': ['counting?', 'the', 'in'],
#  'counting?': ['Welcome'],
#  'quad.': ['It’s'],
#  'pentagon.': ['The'],
#  'whole': ['snarky', 'dollars…', 'pack.'],
#  'snarky': ['Goth'],
#  'Goth': ['girl'],
#  'girl': ['thing', 'detective,', 'if'],
#  'thing': ['might', 'Nevermore', 'about', 'I', 'smash', 'took', 'that'],
#  'worked': ['at'],
#  'normie': ['school,'],
#  'things': ['are', 'weird,'],
#  'Let': ['me'],
#  'wiki': ['on'],
#  'Nevermore’s': ['social'],
#  'social': ['scene.', 'media'],
#  'scene.': ['I’m'],
#  'interested': ['in'],
#  'participating': ['in'],
#  'tribal': ['adolescent'],
#  'adolescent': ['clichés.'],
#  'clichés.': ['Well,'],
#  'Well,': ['then', 'the', 'here’s', 'good'],
#  'use': ['it', 'them.', 'the', 'your', 'it'],
#  'obviously': ['bottomless'],
#  'bottomless': ['pit'],
#  'pit': ['of'],
#  'disdain.': ['There'],
#  'There': ['are', 'wasn’t'],
#  'many': ['flavors', 'terrible'],
#  'flavors': ['of'],
#  'outcasts': ['here,'],
#  'here,': ['but'],
#  'four': ['main', 'o’clock?', 'shots'],
#  'main': ['cliques'],
#  'cliques': ['are'],
#  'Fangs,': ['Furs,', 'AKA'],
#  'Furs,': ['Stoners', 'AKA'],
#  'Stoners': ['and'],
#  'Scales.': ['Those'],
#  'Those': ['are'],
#  'AKA': ['vampires.', 'werewolves.'],
#  'vampires.': ['Some'],
#  'Some': ['of'],
#  'them': ['have', 'to', 'the', 'in', 'held', 'in'],
#  'literally': ['been'],
#  'decades.': ['That'],
#  'bunch': ['of'],
#  'knuckleheads': ['are'],
#  'werewolves.': ['Like'],
#  'me!': ['[Furs'],
#  '[Furs': ['howling]', 'howling,', 'continue'],
#  'howling]': ['Full'],
#  'Full': ['moons'],
#  'moons': ['get'],
#  'pretty': ['loud'],
#  'loud': ['around', 'music,'],
#  'when': ['Furs', 'you', 'am', 'someone', 'I', 'I', 'the', 'he', 'she'],
#  'Furs': ['wolf'],
#  'wolf': ['out.'],
#  'suggest': ['you'],
#  'noise-cancelling': ['headphones.'],
#  'headphones.': ['I’m'],
#  'assuming': ['Scales'],
#  'Scales': ['are'],
#  'sirens?': ['[Enid]'],
#  'catch': ['on', 'your'],
#  'quick.': ['And'],
#  'Bianca': ['Barclay,', 'has'],
#  'Barclay,': ['is'],
#  'closest': ['thing'],
#  'royalty.': ['[enchanting'],
#  '[enchanting': ['whooshing]'],
#  'Although': ['her'],
#  'crown’s': ['been'],
#  'slipping': ['lately.'],
#  'lately.': ['She'],
#  'used': ['to', 'to', 'to'],
#  'date': ['our'],
#  'resident': ['tortured'],
#  'tortured': ['artist,'],
#  'artist,': ['Xavier'],
#  'Xavier': ['Thorpe.', 'Thorpe?'],
#  'Thorpe.': ['But'],
#  'But': ['they', 'it', 'someone', 'drip', 'tears'],
#  'broke': ['up'],
#  'beginning': ['of'],
#  'semester.': ['Reason'],
#  'Reason': ['unknown.'],
#  'unknown.': ['Fascinating.'],
#  'Fascinating.': ['I'],
#  'know,': ['right?', 'but'],
#  'right?': ['My', 'Rowan.'],
#  'vlog': ['is,', 'might'],
#  'is,': ['like,', 'you', 'but,'],
#  'like,': ['the', 'your'],
#  'number': ['one'],
#  'source': ['for'],
#  'gossip.': ['Yo,'],
#  'Enid!': ['You’re'],
#  'believe': ['the', 'that,', 'it?'],
#  'dirt': ['I'],
#  'heard': ['about', 'muffled'],
#  'roommate.': ['She'],
#  'eats': ['human'],
#  'human': ['flesh.'],
#  'flesh.': ['Chowed'],
#  'Chowed': ['down'],
#  'down': ['on', 'and', 'three', 'and'],
#  'murdered.': ['You'],
#  'better': ['watch', 'punctuation.', 'at'],
#  'back.': ['Quite', 'You', 'Just'],
#  'Quite': ['the'],
#  'contrary.': ['I'],
#  'actually': ['fillet'],
#  'fillet': ['the'],
#  'bodies': ['of'],
#  'victims,': ['then'],
#  'feed': ['them'],
#  'menagerie': ['of'],
#  'pets.': ['Ajax,'],
#  'Ajax,': ['this'],
#  'roommate,': ['Wednesday.'],
#  'Whoa.': ['You’re', 'Where’s'],
#  'black': ['and', 'dahlia.', 'and', 'heart', 'cloud.'],
#  'white.': ['Like', '[dramatic'],
#  'living': ['Instagram'],
#  'Instagram': ['filter.'],
#  'filter.': ['Ignore'],
#  'Ignore': ['him.'],
#  'him.': ['Gorgons', 'I', 'You'],
#  'Gorgons': ['spend'],
#  'spend': ['way'],
#  'too': ['much'],
#  'much': ['time', 'online', 'they', 'as'],
#  'getting': ['stoned.', 'your'],
#  'stoned.': ['He’s'],
#  'He’s': ['cute,', 'not', 'dead.', 'sensitive.'],
#  'cute,': ['but'],
#  'clueless.': ['It’s'],
#  'small': ['school.'],
#  'wasn’t': ['much', 'human.', 'here', 'involved.'],
#  'online': ['about'],
#  'should': ['really', 'know'],
#  'really': ['get', 'feel', 'suck', 'obsessed', 'think'],
#  'on\xa0Insta,': ['Snapchat'],
#  'Snapchat': ['and'],
#  'TikTok.': ['I'],
#  'find': ['social', 'it', 'out', 'someone', 'something', 'out'],
#  'media': ['to'],
#  'soul-sucking': ['void'],
#  'void': ['of'],
#  'meaningless': ['affirmation.'],
#  'affirmation.': ['Look'],
#  'Look': ['at'],
#  'deathtrap.': ['Seeing'],
#  'Seeing': ['you'],
#  'uniform': ['brings'],
#  'brings': ['back'],
#  'terrible': ['memories.', 'thing'],
#  'memories.': ['Doesn’t'],
#  'Doesn’t': ['it,'],
#  'it,': ['Tish?', 'you'],
#  'Yes.': ['Why'],
#  'boys': ['wait'],
#  'wait': ['in'],
#  'car?': ['Wednesday'],
#  'need': ['a', 'you', 'a', 'a', 'them.', 'to', 'to', 'to', 'to', 'to'],
#  'moment.': ['[Pugsley'],
#  '[Pugsley': ['grunts]'],
#  'you’re': ['soft',
#   'settling',
#   'going',
#   'gonna',
#   'intent',
#   'thinking,',
#   'here.',
#   'going',
#   'out',
#   'already',
#   'weird',
#   'willing',
#   'in'],
#  'soft': ['and'],
#  'weak.': ['You’ll'],
#  'You’ll': ['never', 'be'],
#  'survive': ['without'],
#  'months,': ['tops.'],
#  'tops.': ['I’m'],
#  'miss': ['you,'],
#  'too,': ['sis.'],
#  'sis.': ['Any'],
#  'Any': ['plans', 'luck'],
#  'plans': ['you', 'involve'],
#  'running': ['away', 'away.'],
#  'end': ['right', 'up'],
#  'now.': ['I’ve', '[mysterious', '[dramatic', '[jauntily'],
#  'alerted': ['all'],
#  'members': ['to'],
#  'contact': ['me'],
#  'minute': ['you'],
#  'darken': ['their'],
#  'doorstep.': ['You'],
#  'nowhere': ['to'],
#  'go.': ['As', 'Wait', 'Wednesday,'],
#  'As': ['usual,', 'much'],
#  'usual,': ['you'],
#  'underestimate': ['me,', 'me.'],
#  'Mother.': ['I', 'I', 'I'],
#  'penitentiary,': ['and'],
#  'again.': ['[sighs]', '[Furs'],
#  'brilliant': ['girl,'],
#  'sometimes': ['you'],
#  'own': ['way.'],
#  'grow': ['to'],
#  'Nevermore,': ['and', 'so', 'because', 'I'],
#  'as': ['life-changing',
#   'I',
#   'it',
#   'a',
#   'gratuitously',
#   'part',
#   'shit,',
#   'a',
#   'it'],
#  'life-changing': ['as'],
#  'did.': ['Oh,'],
#  'something.': ['W…'],
#  'W…': ['M.'],
#  'M.': ['Our'],
#  'Our': ['initials.', 'little', 'first'],
#  'initials.': ['It’s'],
#  'obsidian,': ['which'],
#  'which': ['Aztec'],
#  'Aztec': ['priests'],
#  'priests': ['used'],
#  'conjure': ['visions.'],
#  'symbol': ['of'],
#  'connection.': ['Which', 'Later,'],
#  'Which': ['one'],
#  'spirits': ['suggested'],
#  'suggested': ['this', 'I', 'giving'],
#  'toe-curling': ['tchotchke?'],
#  'tchotchke?': ['I’m'],
#  'love,': ['or'],
#  'or': ['be',
#   'have',
#   'there’s',
#   'perpetuating',
#   'not?',
#   'be',
#   'meaning.',
#   'is',
#   'find',
#   'are',
#   'girl?'],
#  'housewife,': ['or'],
#  'family.': ['I’m'],
#  'told': ['girls'],
#  'girls': ['your'],
#  'age': ['say'],
#  'hurtful': ['things,'],
#  'things,': ['and'],
#  'shouldn’t': ['take', 'procreate.'],
#  'heart.': ['Fortunately,'],
#  'Fortunately,': ['you'],
#  'one.': ['Finally,', 'The', 'I'],
#  'Finally,': ['a'],
#  'kind': ['word', 'of', 'of'],
#  'word': ['for', 'of'],
#  'crystal': ['ball,'],
#  'ball,': ['please.'],
#  'please.': ['We'],
#  'We': ['can’t', 'found', 'work', 'all', 'need', 'can'],
#  'can’t': ['talk', 'prove', 'hide', 'be'],
#  'talk': ['to'],
#  'week': ['while', 'after'],
#  'while': ['you’re'],
#  'settling': ['in,', 'in.'],
#  'in,': ['so'],
#  'we’ll': ['call'],
#  'call': ['you', 'a'],
#  'next': ['Sunday.'],
#  'Sunday.': ['[delicate,'],
#  '[delicate,': ['emotional'],
#  'emotional': ['music'],
#  '[car': ['door'],
#  'door': ['closes]'],
#  'closes]': ['Don’t', 'Your'],
#  'Don’t': ['worry,', 'approve', 'mess', 'tell'],
#  'worry,': ['my'],
#  'scorpion': ['won’t', 'for'],
#  'alone.': ['[undercarriage', 'We'],
#  '[undercarriage': ['clattering]'],
#  'clattering]': ['[fingers', '[fencer'],
#  '[fingers': ['scuttling]'],
#  'scuttling]': ['[thunder'],
#  'booms]': ['Where’s'],
#  'Where’s': ['the', 'the'],
#  'rest': ['of', 'of', 'of', 'of', 'of'],
#  'him?': ['Well,', 'It’s'],
#  'torso': ['and'],
#  'arm': ['are', 'in'],
#  'there.': ['We'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ep01_dict)
# Out:
# 'Look pretty, but clueless. It’s made an obsession with your footsteps. Becoming captain of advice..'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
ep08_text = data.transcript.loc['E08']
ep08_text[:200]
# Out:
# 'Original release date: November\xa023,\xa02022 Wednesday and her classmates lure Tyler into the forest, where they kidnap him. Seeking a confession, Wednesday starts torturing Tyler. Disagreeing with her me'

# %%
ep08_dict = markov_chain(ep08_text)
ep08_dict
# Out:
# {'Original': ['release'],
#  'release': ['date:'],
#  'date:': ['November\xa023,\xa02022'],
#  'November\xa023,\xa02022': ['Wednesday'],
#  'Wednesday': ['and',
#   'starts',
#   'is',
#   'visits',
#   'get',
#   'to',
#   'destroys',
#   'departs',
#   'to'],
#  'and': ['her',
#   'Wednesday',
#   'Wednesday',
#   'subdue',
#   'leaves',
#   'Eugene',
#   'Wednesday',
#   'suddenly',
#   'me',
#   'you',
#   'married',
#   'let',
#   'detached.',
#   'a',
#   'torture?',
#   'cooperation',
#   'trust',
#   'impulsive.',
#   'the',
#   'I',
#   'there',
#   'is',
#   'never',
#   'you',
#   'werewolves,',
#   'waiting.',
#   'I',
#   'renewal.',
#   'those',
#   'just',
#   'the',
#   'pin',
#   'shut',
#   'her',
#   'confronted',
#   'I',
#   'Thornhill',
#   'Wednesday’s',
#   'if',
#   'whine',
#   'be',
#   'I',
#   'for',
#   'true.',
#   'you',
#   'Kent?',
#   'then',
#   'alert',
#   'I',
#   'forever.',
#   'heal',
#   'calmly,',
#   'drizzle',
#   'Tyler',
#   'Ellie',
#   'Frank’s',
#   'Ellie',
#   'Ellie',
#   'flooded',
#   'Ellie'],
#  'her': ['classmates',
#   'methods,',
#   'classmates',
#   'from',
#   'that',
#   'shapeshifting',
#   'true',
#   'werewolf',
#   'torching',
#   'mess.',
#   'personal',
#   'medical',
#   'condition.',
#   'condition',
#   'do',
#   'name',
#   'boots?',
#   'and',
#   'up.',
#   'went',
#   'direct'],
#  'classmates': ['lure', 'alert'],
#  'lure': ['Tyler'],
#  'Tyler': ['into',
#   'finally',
#   'in',
#   'is',
#   'is',
#   'with',
#   'is',
#   'brutally',
#   'is',
#   'used',
#   'warned',
#   'is',
#   'told',
#   'didn’t',
#   'kill',
#   'will',
#   'to',
#   'and',
#   'or',
#   'just'],
#  'into': ['the', 'her', 'that…', 'your'],
#  'the': ['forest,',
#   'police',
#   'monster.',
#   'hospital,',
#   'figure',
#   'monster’s',
#   'school.',
#   'remainder',
#   'semester.',
#   'other',
#   'last',
#   'real',
#   'old',
#   'Rave’N,',
#   'woods',
#   'Gates',
#   'woods',
#   'hell',
#   'chains?',
#   'pack',
#   'monster.',
#   'Weathervane.',
#   'trauma',
#   'body',
#   'basement',
#   'Gates',
#   'circumstances.',
#   'cave,',
#   'panic',
#   'school',
#   'Hyde.',
#   'afternoon',
#   'guards',
#   'cameras.',
#   'Hyde.',
#   'actual',
#   'Hyde,',
#   'same',
#   'past.',
#   'mark',
#   'sight',
#   'disappointment.',
#   'station.',
#   'time.',
#   'dance.',
#   'dance',
#   'monster’s.',
#   'woods,',
#   'act,',
#   'outcasts',
#   'Galpin',
#   'cave',
#   'shackles.',
#   'truth,',
#   'situation.',
#   'station.',
#   'station.',
#   'Bumblebee”',
#   'bad',
#   'conservatory.',
#   'hell',
#   'heck?',
#   'Nightshades?',
#   'way.',
#   'sheriff.',
#   'boat.',
#   'way',
#   'centuries,',
#   'outcasts.',
#   'dead.',
#   'one',
#   'original',
#   'key.',
#   'chubby',
#   'key.',
#   'night',
#   'squad',
#   'world',
#   'same',
#   'eternal',
#   'deal',
#   'school',
#   'fire',
#   'other',
#   'only',
#   'middle',
#   'woods?',
#   'hell’s',
#   'school.',
#   'first',
#   'outcasts,',
#   'sheriff?',
#   'one',
#   'semester,',
#   'cell',
#   '21st',
#   'dark',
#   'suspense',
#   'infected.',
#   'planet,',
#   'Loft.'],
#  'forest,': ['where'],
#  'where': ['they', 'that'],
#  'they': ['kidnap',
#   'are',
#   'would',
#   'weren’t',
#   'did',
#   'confront',
#   'stole',
#   'come'],
#  'kidnap': ['him.'],
#  'him.': ['Seeking', 'But', 'I’m'],
#  'Seeking': ['a'],
#  'a': ['confession,',
#   'date?',
#   'surprise.',
#   'masterstroke',
#   'monster.',
#   'normie.',
#   'monster.',
#   'lie.',
#   'vision',
#   'mark.',
#   'Hyde',
#   'different',
#   'problem.',
#   'miracle',
#   'police',
#   'question.',
#   'fear',
#   'variety',
#   'student',
#   'Hyde!',
#   'vision',
#   'rainbow',
#   'pop',
#   'sign',
#   'school',
#   'good',
#   'text',
#   'lot',
#   'parting',
#   'very',
#   'Hyde.',
#   'moment,',
#   'job',
#   'bit',
#   'plant-derived',
#   'girl.',
#   'monster.',
#   'bigger',
#   'full',
#   'peep',
#   'really',
#   'moron.',
#   'déjà',
#   'child.',
#   'good',
#   'line',
#   'visionary,',
#   'school.',
#   'different',
#   'blood',
#   'blood',
#   'situation.',
#   'couple',
#   'secret',
#   'psycho?',
#   'panic',
#   'secret',
#   'powerful',
#   'conduit',
#   'cockroach.',
#   'gun',
#   'sword',
#   'real',
#   'thank-you.',
#   'free',
#   'lot',
#   'warning',
#   'lot',
#   'bold',
#   'text,',
#   'text',
#   'bigger',
#   'stranger',
#   'group',
#   'fungal',
#   'mission'],
#  'confession,': ['Wednesday'],
#  'starts': ['torturing'],
#  'torturing': ['Tyler.'],
#  'Tyler.': ['Disagreeing', 'Wounding', 'You', 'Son,'],
#  'Disagreeing': ['with'],
#  'with': ['her',
#   'Wednesday’s',
#   'us.',
#   'the',
#   'her,',
#   'deeper',
#   'this.',
#   'your',
#   'Yoko.',
#   'you.',
#   'Weems',
#   'me?',
#   'a',
#   'Thornhill',
#   'Nevermore.',
#   'a',
#   'a',
#   'a'],
#  'methods,': ['her'],
#  'alert': ['Weems,', 'Tyler'],
#  'Weems,': ['and', 'explain'],
#  'is': ['arrested.',
#   'able',
#   'released',
#   'detained,',
#   'closing',
#   'nuts.',
#   'crazy.',
#   'that',
#   'always',
#   'Kinbott,',
#   'a',
#   'our',
#   'going',
#   'your',
#   'the',
#   'no',
#   'looping',
#   'the',
#   'make',
#   'indelible.',
#   'admittedly',
#   'still',
#   'kind',
#   'a',
#   'that',
#   'he',
#   'probably',
#   'Laurel!',
#   'a',
#   'helping.',
#   'going',
#   'a',
#   'here?',
#   'this',
#   'what’s',
#   'the',
#   'a',
#   'also',
#   'on',
#   'that',
#   'this?',
#   'killing',
#   'even'],
#  'arrested.': ['At'],
#  'At': ['the', 'the'],
#  'police': ['station,', 'radio', 'station.'],
#  'station,': ['Tyler'],
#  'finally': ['confesses', 'transformed', 'awake.'],
#  'confesses': ['to'],
#  'to': ['being',
#   'confess',
#   'kill',
#   'die,',
#   'heal',
#   'destroy',
#   'see',
#   'Nevermore,',
#   'their',
#   'spy',
#   'clean',
#   'hand',
#   'you,',
#   'the',
#   'confront',
#   'her',
#   'you.',
#   'me?',
#   'Weems,',
#   'a',
#   'you.',
#   'turn',
#   'talk',
#   'her,',
#   'remember',
#   'do',
#   'have',
#   'do',
#   'be',
#   'me',
#   'be',
#   'me!',
#   'frame',
#   'have',
#   'the',
#   'stop',
#   'miss',
#   'be',
#   'disappointment.',
#   'give',
#   'give.',
#   'elude',
#   'leave',
#   'the',
#   'miss',
#   'get',
#   'be',
#   'die.',
#   'see',
#   'your',
#   'see',
#   'tell',
#   'the',
#   'check',
#   'listen',
#   'me',
#   'stick',
#   'that',
#   'New',
#   'unlock',
#   'you.',
#   'discovering',
#   'your',
#   'intercept',
#   'the',
#   'see',
#   'call',
#   'go.',
#   'help.',
#   'your',
#   'admit…',
#   'outsmart',
#   'Joseph',
#   'protecting',
#   'add',
#   'injury,',
#   'build',
#   'Crackstone’s',
#   'take',
#   'resurrect',
#   'kill',
#   'curse',
#   'do',
#   'be',
#   'rid',
#   'Crackstone’s',
#   'get',
#   'safety',
#   'cause',
#   'convince',
#   'take',
#   'the',
#   'pass',
#   'delay.',
#   'get',
#   'the',
#   'hell.',
#   'a',
#   'kill',
#   'kill',
#   'admit,',
#   'come',
#   'your',
#   'the',
#   'call.',
#   'be',
#   'his',
#   'drop'],
#  'being': ['the', 'serious?', 'your', 'a'],
#  'monster.': ['Fed', 'A…', 'According', 'You', 'If'],
#  'Fed': ['up'],
#  'up': ['with', 'her', 'for', 'naked,', 'last'],
#  'Wednesday’s': ['behavior,', 'blood,', 'been', 'my'],
#  'behavior,': ['Weems', 'but…'],
#  'Weems': ['expels', 'and', 'and', 'won’t', 'was', 'and', 'almost', 'and'],
#  'expels': ['her'],
#  'from': ['Nevermore.',
#   'Bianca,',
#   'prison,',
#   'your',
#   'my',
#   'the',
#   'Nevermore.',
#   'you.',
#   'Eugene’s',
#   'either',
#   'a',
#   'outcasts',
#   'Pilgrim',
#   'thy',
#   'this',
#   'her!',
#   'here.',
#   'the'],
#  'Nevermore.': ['Wednesday', 'The', 'Not', 'Get', 'Bitch.'],
#  'visits': ['Eugene'],
#  'Eugene': ['at', 'helps', 'and', 'probably', 'Ottinger’s'],
#  'at': ['the',
#   'the',
#   'the',
#   'the',
#   'first,',
#   'the',
#   'Nevermore,',
#   'first,',
#   'the',
#   'Nevermore',
#   'Nevermore.',
#   'least',
#   'all'],
#  'hospital,': ['who'],
#  'who': ['tells', 'claims', 'you', 'nearly', 'would'],
#  'tells': ['her'],
#  'that': ['the',
#   'night',
#   'was',
#   'I',
#   'something',
#   'a',
#   'claw',
#   'Tyler',
#   'also',
#   'might',
#   'got',
#   'makes',
#   'cave.',
#   'it',
#   'they',
#   'truth',
#   'train.',
#   'go',
#   'abomination',
#   'cause.',
#   'stole',
#   'really',
#   'classes',
#   'fencing',
#   'is',
#   'could'],
#  'figure': ['he'],
#  'he': ['saw',
#   'morphs',
#   'snaps,',
#   'has',
#   'kissed',
#   'tries',
#   'told',
#   'willingly',
#   'killing',
#   'doing',
#   'will',
#   'relive'],
#  'saw': ['at', 'her', 'it', 'it', 'someone', 'that'],
#  'monster’s': ['cave'],
#  'cave': ['wore', 'in', 'and'],
#  'wore': ['red'],
#  'red': ['boots,'],
#  'boots,': ['matching'],
#  'matching': ['Ms.'],
#  'Ms.': ['Thornhill’s.', 'Thornhill.', 'Thornhill?'],
#  'Thornhill’s.': ['Using'],
#  'Using': ['her', 'Wednesday’s'],
#  'shapeshifting': ['powers,'],
#  'powers,': ['Weems'],
#  'get': ['Thornhill',
#   'involved,',
#   'hurt.',
#   'you',
#   'everyone',
#   'everyone',
#   'you',
#   'back',
#   'to',
#   'to',
#   'for',
#   'to'],
#  'Thornhill': ['to', 'took', 'being'],
#  'confess': ['her'],
#  'true': ['identity—Laurel', 'if'],
#  'identity—Laurel': ['Gates.'],
#  'Gates.': ['However,', 'Xavier'],
#  'However,': ['Gates'],
#  'Gates': ['is', 'resurrects', 'mansion,', 'mansion,', 'and'],
#  'able': ['to'],
#  'kill': ['Weems', 'her?', 'her', 'Crackstone.', 'all', 'you,'],
#  'subdue': ['Wednesday.'],
#  'Wednesday.': ['Using',
#   'Pack',
#   'I’m',
#   'I',
#   'This',
#   'I',
#   'Once',
#   'Okay,',
#   'Are',
#   '[delicate,',
#   '[bee'],
#  'blood,': ['Gates', 'no'],
#  'resurrects': ['Crackstone'],
#  'Crackstone': ['and', 'breaches', 'was', 'in', 'must'],
#  'leaves': ['Wednesday'],
#  'die,': ['but'],
#  'but': ['Goody', 'I', 'I’m', 'they’re', 'at', 'I'],
#  'Goody': ['appears', 'Addams.', 'Addams', 'to', 'sealed', 'Addams.'],
#  'appears': ['to'],
#  'heal': ['her.', 'you.'],
#  'her.': ['Enid,', 'She', 'I'],
#  'Enid,': ['having'],
#  'having': ['finally'],
#  'transformed': ['into'],
#  'werewolf': ['form,'],
#  'form,': ['defeats'],
#  'defeats': ['Tyler'],
#  'in': ['his',
#   'his',
#   'the',
#   'love',
#   'dread,',
#   'a',
#   'the',
#   'here!',
#   'a',
#   'blood,',
#   'their',
#   'an',
#   'a',
#   'with',
#   'the',
#   'touch,',
#   'the',
#   'town.',
#   'a',
#   'your',
#   'trouble,',
#   'eradicating',
#   'motion.',
#   'his',
#   'Latin]',
#   'the',
#   'a',
#   'the',
#   'unison]',
#   'the',
#   'San',
#   'the',
#   'there',
#   'the',
#   'a'],
#  'his': ['Hyde',
#   'pursuit',
#   'life',
#   'father.',
#   'mother',
#   'mother',
#   'mother',
#   'life',
#   'land',
#   'soul',
#   'sarcophagus',
#   'black',
#   'daughter',
#   'compound,'],
#  'Hyde': ['form', 'helped', 'understands.'],
#  'form': ['while'],
#  'while': ['Crackstone', 'the', 'I'],
#  'breaches': ['Nevermore'],
#  'Nevermore': ['in', 'didn’t', 'set'],
#  'pursuit': ['to'],
#  'destroy': ['the'],
#  'school.': ['With', 'But,', 'I', 'For'],
#  'With': ['help'],
#  'help': ['from'],
#  'Bianca,': ['Wednesday', 'Davina…'],
#  'destroys': ['Crackstone,'],
#  'Crackstone,': ['and'],
#  'helps': ['defeat'],
#  'defeat': ['Gates.'],
#  'Xavier': ['is', 'warned', 'for', 'Thorpe'],
#  'released': ['from'],
#  'prison,': ['Tyler'],
#  'detained,': ['and'],
#  'departs': ['Nevermore,'],
#  'Nevermore,': ['which', 'romance', 'unlocking'],
#  'which': ['is'],
#  'closing': ['for'],
#  'for': ['the',
#   'murder',
#   'this.',
#   'Sheriff',
#   'you,',
#   'what’s',
#   'a',
#   'well-executed',
#   'my',
#   'me.',
#   'Goody',
#   'all.',
#   'Wednesday.',
#   'conjuring',
#   'conjuring',
#   'you.',
#   'this',
#   'my',
#   'messing',
#   'the',
#   'the',
#   'me.',
#   'a'],
#  'remainder': ['of'],
#  'of': ['the',
#   'your',
#   'misdirection.',
#   'sick',
#   'here.',
#   'his',
#   'losing',
#   'the',
#   'their',
#   'their',
#   'our',
#   'a',
#   'you.',
#   'weakness.',
#   'it',
#   'sneaky',
#   'gorgons,',
#   'our\xa0thing.',
#   'people',
#   'time.',
#   'nature’s',
#   'it.',
#   'light',
#   'using',
#   'the',
#   'them.',
#   'a',
#   'psychotic',
#   'a',
#   'Shadows.',
#   'my',
#   'her',
#   'a',
#   'your',
#   'outcasts',
#   'hell.',
#   'the',
#   'here!',
#   'us.',
#   'people',
#   'Jericho.',
#   'Fireflies.'],
#  'semester.': ['*'],
#  '*': ['*', '*', '[low,', 'Name*'],
#  '[low,': ['menacing', 'arcane', 'somber'],
#  'menacing': ['music'],
#  'music': ['playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'builds,',
#   'playing]',
#   'playing]',
#   'playing]',
#   'building]',
#   'playing]',
#   'builds]',
#   'playing]',
#   'playing',
#   'playing]',
#   'fades',
#   'playing]',
#   'continues]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'rises]',
#   'builds]',
#   'plays]',
#   'plays]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]'],
#  'playing]': ['Thing',
#   'Welcome',
#   '[tasers',
#   '[Kinbott]',
#   'You',
#   'I',
#   '[Xavier',
#   'I’m…',
#   'Thanks.',
#   'The',
#   'That',
#   'Your',
#   '[upbeat',
#   'Slow',
#   '[Laurel]',
#   '[choir',
#   '[Laurel',
#   '[faint',
#   '[rousing',
#   '[Xavier',
#   '[grunting,',
#   '[students',
#   '[Crackstone’s',
#   '[Ajax]',
#   'Where’s',
#   'My',
#   '[Wednesday]',
#   'Your'],
#  'Thing': ['gave', 'did.', 'distracted', 'and'],
#  'gave': ['me', 'you'],
#  'me': ['your',
#   'again',
#   'about',
#   'put',
#   'discussing',
#   'out',
#   'alone?',
#   'a',
#   'here',
#   'with',
#   'and',
#   'more',
#   'to',
#   'something',
#   'up.',
#   'in',
#   'is',
#   'to',
#   'to',
#   'moisturizing',
#   'this',
#   'everything.',
#   'still.',
#   'to',
#   'it’s',
#   'to',
#   'again.',
#   'in',
#   'to'],
#  'your': ['note.',
#   'secret',
#   'sessions.',
#   'cave',
#   'screams.',
#   'garage.',
#   'father',
#   'own.',
#   'reflexes.',
#   'immediate',
#   'suspicions',
#   'own',
#   'ability',
#   'own',
#   'own',
#   'steamer',
#   'goodbyes.',
#   'mother',
#   'friend.',
#   'creepy,',
#   'way',
#   'train.',
#   'fault.',
#   'bees.',
#   'death,',
#   'father',
#   'servant.',
#   'side.',
#   'mother…',
#   'room?',
#   'master',
#   'ancestor,',
#   'ancestor',
#   'blood.',
#   'spectral',
#   'little',
#   'heroes.',
#   'head.',
#   'friend'],
#  'note.': ['I'],
#  'I': ['was',
#   'came',
#   'didn’t',
#   'don’t',
#   'know.',
#   'thought',
#   'told',
#   'was',
#   'have',
#   'was,',
#   'was',
#   'don’t',
#   'hadn’t',
#   'would',
#   'saw',
#   'mean,',
#   'won’t',
#   'didn’t',
#   'press',
#   'believe',
#   'suspected.',
#   'say',
#   'don’t',
#   'gave',
#   'need',
#   'started',
#   'could',
#   'acted',
#   'should',
#   'admire',
#   'wish',
#   'could',
#   'didn’t',
#   'can',
#   'know',
#   'saw',
#   'was',
#   'should’ve',
#   'was',
#   'tried',
#   'think…',
#   'don’t',
#   'can’t',
#   'assume',
#   'grow',
#   'guess.',
#   'always',
#   'promise.',
#   'got',
#   'think',
#   'caught',
#   'was',
#   'just',
#   'can’t',
#   'have',
#   'heard',
#   'shouldn’t',
#   'should',
#   'thought',
#   'don’t',
#   'just',
#   'saw',
#   'thought',
#   'should',
#   'have',
#   'incorrectly',
#   'know',
#   'assume',
#   'told',
#   'showed',
#   'sent',
#   'never',
#   'think.',
#   'haven’t',
#   'will',
#   'won’t',
#   'have',
#   'decided',
#   'believe',
#   'bided',
#   'made',
#   'can’t.',
#   'am',
#   'have',
#   'can’t',
#   'will',
#   'do,',
#   'need',
#   'can’t',
#   'will',
#   'will',
#   'will',
#   'might',
#   'hate',
#   'am',
#   'have',
#   'can',
#   'owe',
#   'hear',
#   'was',
#   'said',
#   'don’t',
#   'hope',
#   'imagined.',
#   'know'],
#  'was': ['surprised',
#   'the',
#   'visiting',
#   'a',
#   'alone?',
#   'an',
#   'a\xa0Hyde.',
#   'she',
#   'my',
#   'delicious.',
#   'an',
#   'a',
#   'a',
#   'falsely',
#   'curious',
#   'coming.',
#   'weeding',
#   'her.',
#   'an',
#   'you.',
#   'a',
#   'right.',
#   'scary',
#   'a',
#   'cut',
#   'tough.',
#   'one',
#   'in'],
#  'surprised': ['you'],
#  'you': ['wanted',
#   'ran',
#   'kissed',
#   'opened',
#   'don’t',
#   'kill',
#   'I',
#   'to',
#   'overheard',
#   'warned',
#   'to',
#   'know',
#   'sound',
#   'really',
#   'risk',
#   'recognize',
#   'all',
#   'had',
#   'can',
#   'doing?',
#   'being',
#   'for?',
#   'doing',
#   'known?',
#   'that',
#   'already',
#   'one',
#   'too.',
#   'doing?',
#   'want?',
#   'certainly',
#   'impatient',
#   'must',
#   'doing',
#   'know?',
#   'were',
#   'seem',
#   'get',
#   'ever',
#   'want',
#   'understand?',
#   'save',
#   'forget',
#   'have',
#   'kidding',
#   'literally',
#   'drop',
#   'better',
#   'expelled.',
#   'do',
#   'to',
#   'visited',
#   'gotta',
#   'have',
#   'used',
#   'about',
#   'were',
#   'targeted',
#   'used',
#   'had',
#   'who',
#   'really',
#   'a',
#   'only',
#   'think?',
#   'okay?',
#   'seen',
#   'want',
#   'got',
#   'come',
#   'are',
#   'feel',
#   'were',
#   'to',
#   'bequeathed',
#   'belong.',
#   'didn’t',
#   'know,',
#   'here',
#   'and',
#   'will',
#   'asshole!',
#   'were',
#   'nowhere.',
#   'how',
#   'abominations',
#   'back',
#   'get',
#   'have',
#   'a',
#   'going'],
#  'wanted': ['to'],
#  'see': ['me', 'what', 'you’re', 'you?', 'me'],
#  'again': ['after'],
#  'after': ['you', 'we', 'a'],
#  'ran': ['out'],
#  'out': ['the',
#   'to',
#   'of',
#   'for',
#   'I’ve',
#   'there.',
#   'wild',
#   'on',
#   'the',
#   'of'],
#  'other': ['night.', 'people', 'side?'],
#  'night.': ['So,', 'Maybe'],
#  'So,': ['uh,', 'go.', 'we’re', 'what’s'],
#  'uh,': ['is\xa0this'],
#  'is\xa0this': ['a'],
#  'date?': ['It’s'],
#  'It’s': ['a',
#   'like',
#   'not',
#   'the',
#   'actually',
#   'still',
#   'so',
#   'hive',
#   'happening!',
#   'probably'],
#  'surprise.': ['[wry'],
#  '[wry': ['chuckle]'],
#  'chuckle]': ['When', '[gloomy'],
#  'When': ['I', 'I', 'I', 'the', 'I', 'a'],
#  'came': ['to', 'close'],
#  'romance': ['was'],
#  'last': ['thing', 'night.'],
#  'thing': ['on', 'that', 'we', 'she'],
#  'on': ['my',
#   'me?',
#   'to',
#   'your',
#   'his',
#   'you',
#   'the',
#   'this?',
#   'me',
#   'other',
#   'your',
#   'your',
#   'all',
#   'Xavier.',
#   'your',
#   'that',
#   'me,',
#   'the',
#   'the',
#   'at',
#   'the',
#   'my',
#   'its',
#   'their'],
#  'my': ['mind.',
#   'eyes',
#   'own',
#   'son!',
#   'friend.',
#   'help?',
#   'life!',
#   'ears',
#   'wolfsbane,',
#   'high',
#   'only',
#   'father',
#   'family',
#   'plan',
#   'time,',
#   'way.',
#   'God.',
#   'God!\xa0Oh',
#   'God!\xa0Oh',
#   'God!',
#   'family.',
#   'God!',
#   'novel,'],
#  'mind.': ['But'],
#  'But': ['when',
#   'over',
#   'that',
#   'since',
#   'it',
#   'yours',
#   'you',
#   'eventually',
#   'this',
#   'I',
#   'as',
#   'she'],
#  'when': ['you', 'he', 'Tyler', 'you', 'Kinbott'],
#  'kissed': ['me,', 'me.'],
#  'me,': ['you', 'are', 'I’ve'],
#  'opened': ['my'],
#  'eyes': ['and', 'waking'],
#  'suddenly': ['it'],
#  'it': ['all',
#   'to',
#   'in',
#   'quick.',
#   'feel',
#   'was',
#   'in',
#   'is',
#   'kills',
#   'again.',
#   'was',
#   'was',
#   'on',
#   'to',
#   'already',
#   'means',
#   'from'],
#  'all': ['made',
#   'gonna',
#   'this',
#   'set.',
#   'the',
#   'the',
#   'the',
#   'right?',
#   'the',
#   'costs,',
#   'those'],
#  'made': ['sense.', 'you', 'it', 'you', 'today.'],
#  'sense.': ['[confused'],
#  '[confused': ['scoff]'],
#  'scoff]': ['Xavier', '[tense'],
#  'warned': ['me', 'Kinbott.', 'me'],
#  'about': ['you,',
#   'us,',
#   'you!',
#   'you?',
#   'me?',
#   'her',
#   'the',
#   'Wednesday?',
#   'me?'],
#  'you,': ['but',
#   'Tyler.',
#   'please!',
#   'Wednesday.',
#   'Wednesday.',
#   'Wednesday.',
#   'Wednesday.'],
#  'didn’t': ['listen.',
#   'sign',
#   'have',
#   'ask',
#   'work',
#   'you?',
#   'realize',
#   'tell'],
#  'listen.': ['Ironic'],
#  'Ironic': ['now,', 'would’ve'],
#  'now,': ['huh?'],
#  'huh?': ['Ironic', 'Except'],
#  'would’ve': ['been'],
#  'been': ['framing',
#   'so',
#   'living',
#   'hallmarks',
#   'the',
#   'meaning',
#   'with',
#   'taken,',
#   'collecting',
#   'slashed.',
#   'tied'],
#  'framing': ['Xavier'],
#  'murder': ['while'],
#  'real': ['Hyde', 'pain.'],
#  'helped': ['me'],
#  'put': ['him', 'me'],
#  'him': ['away.', 'on', 'by', 'what', 'to'],
#  'away.': ['Wait…'],
#  'Wait…': ['you'],
#  'don’t': ['think…',
#   'think.',
#   'know',
#   'leave',
#   'understand.',
#   'care!',
#   'really',
#   'you',
#   'want',
#   'let',
#   'know'],
#  'think…': ['I', 'I'],
#  'think.': ['I', 'But'],
#  'know.': ['Kinbott'],
#  'Kinbott': ['probably', 'send', 'of', 'came'],
#  'probably': ['discovered', 'saw', 'still', 'the'],
#  'discovered': ['your'],
#  'secret': ['during', 'when', 'society', 'snap'],
#  'during': ['one'],
#  'one': ['of',
#   'can',
#   'thing',
#   'step',
#   'pass.',
#   'of',
#   'final',
#   'man',
#   'that',
#   'of',
#   'thing',
#   'of',
#   'supernatural'],
#  'sessions.': ['So'],
#  'So': ['she', 'I', 'I', 'you', 'do', 'how', 'don’t'],
#  'she': ['unlocked',
#   'sent',
#   'passed',
#   'collecting',
#   'identified',
#   'left',
#   'swing',
#   'was',
#   'died',
#   'truly'],
#  'unlocked': ['you.'],
#  'you.': ['Why’d',
#   'Are',
#   'That’s',
#   'His',
#   'He',
#   'But',
#   'So',
#   '[subdued,',
#   'Part',
#   'I',
#   'When',
#   'Faking',
#   'That',
#   'I',
#   'Just',
#   '[clothing',
#   '[jauntily'],
#  'Why’d': ['you'],
#  'her?': ['I', 'Perhaps', 'Where?'],
#  'thought': ['Hydes', 'that', 'hummers', 'you’d'],
#  'Hydes': ['were'],
#  'were': ['typically',
#   'getting',
#   'supposed',
#   'red.',
#   'just',
#   'never',
#   'ready',
#   'dead.'],
#  'typically': ['loyal'],
#  'loyal': ['to'],
#  'their': ['masters.', 'screams,', 'eyes,', 'body', 'entire', 'way'],
#  'masters.': ['Wednesday,'],
#  'Wednesday,': ['this',
#   'this',
#   'what',
#   'hold',
#   'I',
#   'please.',
#   'that’s',
#   'wait.',
#   'you'],
#  'this': ['is',
#   'is',
#   'photo,',
#   'to',
#   'off',
#   'time.',
#   'more',
#   'is',
#   'afternoon.',
#   'have',
#   'club?',
#   'moment,',
#   'Earth!',
#   'school.',
#   'forced'],
#  'nuts.': ['On'],
#  'On': ['Outreach', 'a'],
#  'Outreach': ['Day,'],
#  'Day,': ['I'],
#  'told': ['you', 'me', 'you', 'you?', 'me'],
#  'visiting': ['the'],
#  'old': ['meeting'],
#  'meeting': ['house.'],
#  'house.': ['[Hyde'],
#  '[Hyde': ['snarls]'],
#  'snarls]': ['Did'],
#  'Did': ['Kinbott'],
#  'send': ['you', 'you'],
#  'spy': ['on'],
#  'me?': ['At', 'Uh,', 'When', 'Enid…', 'I’ve', 'My', 'What…'],
#  'Rave’N,': ['you'],
#  'overheard': ['Eugene'],
#  'discussing': ['your'],
#  'woods': ['and', 'to'],
#  'Kinbott.': ['Eugene', 'It’s'],
#  'torching': ['it.'],
#  'it.': ['Then',
#   'I’m',
#   'Drop',
#   '[hammer',
#   'And',
#   'I',
#   'You',
#   '[Galpin]',
#   'Hey,'],
#  'Then': ['she', 'you’re', 'give', 'leave.'],
#  'sent': ['you', 'Tyler'],
#  'clean': ['up'],
#  'mess.': ['I'],
#  'have': ['to',
#   'noticed',
#   'left',
#   'a',
#   'you',
#   'no',
#   'no',
#   'guts',
#   'always',
#   'put',
#   'them',
#   'some',
#   'left',
#   'a',
#   'one',
#   'gone',
#   'been',
#   'to',
#   'known',
#   'great',
#   'to',
#   'roots',
#   'to',
#   'been',
#   'summoned',
#   'to',
#   'immense',
#   'to'],
#  'hand': ['it'],
#  'Wounding': ['yourself'],
#  'yourself': ['that'],
#  'night': ['at', 'in', 'of'],
#  'mansion,': ['that', 'what'],
#  'masterstroke': ['of'],
#  'misdirection.': ['Okay,'],
#  'Okay,': ['stop.', 'I', 'Nightshades'],
#  'stop.': ['Do'],
#  'Do': ['you', 'you', 'you', 'you'],
#  'know': ['how', 'what', 'that’s', 'you’re', 'your', 'a', 'what', 'the'],
#  'how': ['insane', 'much', 'you', 'are', 'do', 'I’ve'],
#  'insane': ['you'],
#  'sound': ['right', 'of'],
#  'right': ['now?'],
#  'now?': ['I’m'],
#  'I’m': ['not',
#   'out',
#   'a',
#   'not',
#   'out!',
#   'done.',
#   'begging',
#   'talking',
#   'increasingly',
#   'in',
#   'giving',
#   'sorry',
#   'sure',
#   'not',
#   'actually',
#   'not',
#   'going',
#   'so',
#   'personally',
#   'so',
#   'okay,',
#   'on',
#   'dying.',
#   'wolfing',
#   'feeling',
#   'fine.'],
#  'not': ['a',
#   'she',
#   'the',
#   'pressing',
#   'sure',
#   'the',
#   'here.',
#   'here.',
#   'your',
#   'on',
#   'gonna,',
#   'end',
#   'get',
#   'expecting',
#   'every',
#   'be'],
#  'A…': ['And'],
#  'And': ['if',
#   'your',
#   'Tyler',
#   'her',
#   'it',
#   'he',
#   'say',
#   'so',
#   'you',
#   'you',
#   'when',
#   'then,',
#   'she'],
#  'if': ['you', 'I', 'you’d', 'you’ve', 'you’re', 'I’m', 'she’s'],
#  'really': ['thought', 'remember', 'are.', 'bad', 'you?'],
#  'was,': ['why'],
#  'why': ['would', 'I’m', 'you', 'is'],
#  'would': ['you', 'have', 'lead', 'enslave', 'they', 'disagree.', 'take'],
#  'risk': ['bringing'],
#  'bringing': ['me'],
#  'confront': ['me', 'Ms.'],
#  'alone?': ['Who', 'Okay,'],
#  'Who': ['said', 'are'],
#  'said': ['I', 'you', 'a'],
#  'what': ['kind',
#   'are',
#   'was',
#   'are',
#   'feel',
#   'happened.',
#   'needed',
#   'she',
#   'you',
#   'his',
#   'I',
#   'the',
#   'it',
#   'you',
#   'a',
#   'happened'],
#  'kind': ['of', 'of'],
#  'sick': ['joke'],
#  'joke': ['you’re'],
#  'you’re': ['playing,',
#   'coming',
#   'basing',
#   'on',
#   'not',
#   'not',
#   'finally',
#   'in',
#   'a',
#   'not'],
#  'playing,': ['but'],
#  'here.': ['Actually…', '[indistinct', 'That’s', 'But', 'Maybe'],
#  'Actually…': ['you’re'],
#  'coming': ['with'],
#  'us.': ['[disconcerting', 'Now'],
#  '[disconcerting': ['audio'],
#  'audio': ['distortions]', 'echoes]'],
#  'distortions]': ['[snaps]'],
#  '[snaps]': ['[tense,'],
#  '[tense,': ['unnerving'],
#  'unnerving': ['music'],
#  'Welcome': ['back.', 'to'],
#  'back.': ['Where', 'Do', 'What’s'],
#  'Where': ['the', 'you'],
#  'hell': ['am', 'is'],
#  'am': ['I?', 'I.', 'of', 'gonna'],
#  'I?': ['Somewhere'],
#  'Somewhere': ['no'],
#  'no': ['one', 'idea', 'idea', 'friends,', 'more', 'more'],
#  'can': ['hear', 'trust?', 'prove', 'drop', 'open', 'pretty'],
#  'hear': ['your', 'a', 'you’re'],
#  'screams.': ['What’s'],
#  'What’s': ['with', 'gonna', 'he'],
#  'chains?': ['Don’t'],
#  'Don’t': ['ask', 'worry,', 'ever', 'make'],
#  'ask': ['stupid', 'a', 'what'],
#  'stupid': ['questions.'],
#  'questions.': ['Wednesday,'],
#  'crazy.': ['I’m'],
#  'normie.': ['That’s'],
#  'That’s': ['only', 'it.', 'why', 'how', 'why', 'enough.', 'just', 'a'],
#  'only': ['half', 'one', 'hate', 'friend,', 'way'],
#  'half': ['true.'],
#  'true.': ['Do', 'Tyler', 'As'],
#  'recognize': ['her?'],
#  'Perhaps': ['if', 'if'],
#  'hadn’t': ['been'],
#  'so': ['distracted',
#   'primal',
#   'am',
#   'much',
#   'glad',
#   'crazy',
#   'sorry.',
#   'you'],
#  'distracted': ['by', 'the'],
#  'by': ['my', 'on', 'now.', 'showing', 'to', 'the', 'your'],
#  'own': ['mother', 'hands,', 'person', 'instincts.'],
#  'mother': ['hogging', 'or', 'may', 'was', 'will', 'truly', 'told'],
#  'hogging': ['this'],
#  'photo,': ['I'],
#  'noticed': ['yours'],
#  'yours': ['sooner.', 'was'],
#  'sooner.': ['Your'],
#  'Your': ['father',
#   'father’s',
#   'actions',
#   'slave',
#   'arrival',
#   'necklace.',
#   'email'],
#  'father': ['fell', 'has', 'kept', 'always'],
#  'fell': ['in'],
#  'love': ['and'],
#  'married': ['an'],
#  'an': ['outcast.',
#   'outcast.',
#   'impossible',
#   'outcast.',
#   'eff',
#   'explosion',
#   'outcast,',
#   'arrow',
#   'unlikely',
#   'abandoned'],
#  'outcast.': ['[Tyler]', 'That', 'She'],
#  '[Tyler]': ['My', 'I’m'],
#  'My': ['mom',
#   'mom',
#   'name',
#   'brother',
#   'dear',
#   'vengeance',
#   'mother',
#   'number’s',
#   'very'],
#  'mom': ['was', 'had', 'just'],
#  'That': ['doesn’t', 'can’t', 'inevitably', 'night', 'was', 'gorgon'],
#  'doesn’t': ['make'],
#  'make': ['me', 'things', 'Mama', 'this'],
#  'According': ['to'],
#  'personal': ['medical'],
#  'medical': ['records…', 'records?'],
#  'records…': ['You'],
#  'You': ['stole',
#   'are.',
#   'know,',
#   'have',
#   'mean',
#   'do',
#   'want',
#   'ruined',
#   'can’t',
#   'can',
#   'do',
#   'manipulated',
#   'were',
#   'know,',
#   'can’t',
#   'are',
#   'haunt',
#   'will',
#   'tracking',
#   'shut',
#   'brought',
#   'know'],
#  'stole': ['her', 'his', 'the'],
#  'records?': ['Technically,'],
#  'Technically,': ['Thing'],
#  'did.': ['He'],
#  'He': ['took', 'confessed', 'is', 'woke'],
#  'took': ['them', 'her?', 'Wednesday'],
#  'them': ['from', 'for?', 'shipped.', 'out'],
#  'garage.': ['Your'],
#  'father’s': ['quite'],
#  'quite': ['the', 'sure'],
#  'pack': ['rat.'],
#  'rat.': ['Her'],
#  'Her': ['postpartum'],
#  'postpartum': ['depression'],
#  'depression': ['triggered'],
#  'triggered': ['her'],
#  'condition.': ['My'],
#  'had': ['severe', 'after', 'nothing', 'an', 'Tyler', 'to'],
#  'severe': ['bipolar'],
#  'bipolar': ['disorder.'],
#  'disorder.': ['We'],
#  'We': ['both', 'have', 'will', 'have', 'don’t'],
#  'both': ['know'],
#  'that’s': ['a', 'enough.', 'happened.', 'what'],
#  'lie.': ['She'],
#  'She': ['was', 'was', 'was', 'was', 'had', 'murdered', 'could', 'was'],
#  'a\xa0Hyde.': ['And', 'Typically,'],
#  'has': ['been', 'framed', 'remained', 'been'],
#  'living': ['his', 'descendant'],
#  'life': ['in', 'was'],
#  'dread,': ['never'],
#  'never': ['quite', 'come', 'had', 'getting', 'made', 'see'],
#  'sure': ['whether', 'your', 'how'],
#  'whether': ['or'],
#  'or': ['not', 'any', 'should', 'hear', 'Thornhill.', 'I'],
#  'passed': ['her'],
#  'condition': ['on'],
#  'Are': ['you', 'you', 'you', 'you', 'you'],
#  'gonna': ['stand', 'happen?', 'miss'],
#  'stand': ['there'],
#  'there': ['and', 'are', 'ASAP.', 'already.'],
#  'let': ['her', 'you', 'killing'],
#  'do': ['this',
#   'you',
#   'with',
#   'what',
#   'realize',
#   'you',
#   'is',
#   'next.',
#   'need',
#   'anything',
#   'with',
#   'we',
#   'we'],
#  'Uh,': ['guys?'],
#  'guys?': ['Enid'],
#  'Enid': ['just'],
#  'just': ['texted.',
#   'completely',
#   'saw',
#   'for',
#   'a',
#   'pawns',
#   'a',
#   'called,',
#   'it,',
#   'pawns'],
#  'texted.': ['Thornhill’s'],
#  'Thornhill’s': ['suspicious.'],
#  'suspicious.': ['How'],
#  'How': ['long', 'long', 'do', 'exclusive', 'canst'],
#  'long': ['until', 'have'],
#  'until': ['he', 'his', 'you'],
#  'morphs': ['into'],
#  'that…': ['thing?'],
#  'thing?': ['I’m'],
#  'are.': ['I', 'What'],
#  'vision': ['at', 'you', 'when', 'impaired?'],
#  'Weathervane.': ['Wait,'],
#  'Wait,': ['you’re'],
#  'basing': ['all'],
#  'off': ['some', 'with'],
#  'some': ['vision', 'light', 'action', 'psychic', 'sort'],
#  'we': ['kissed?',
#   'could’ve',
#   'have.',
#   'have',
#   'need',
#   'got',
#   'have',
#   'got',
#   'pull',
#   'get',
#   'stopping',
#   'should'],
#  'kissed?': ['I'],
#  'mean,': ['is'],
#  'something': ['you', 'bad', 'that'],
#  'trust?': ['[Bianca]'],
#  '[Bianca]': ['Wednesday,', 'Wednesday,'],
#  'are': ['you',
#   'you',
#   'you',
#   'Hydes.',
#   'no',
#   'you',
#   'going',
#   'you?',
#   'you?',
#   'the',
#   'the',
#   'the',
#   'canceled',
#   'you',
#   'still',
#   'marked',
#   'tasked'],
#  'doing?': ['Just', 'I'],
#  'Just': ['some', 'like', 'know,'],
#  'light': ['torture.', 'on', 'and'],
#  'torture.': ['Don’t'],
#  'worry,': ['I'],
#  'won’t': ['leave', 'help.', 'be', 'cry'],
#  'leave': ['a', 'me', 'when', 'Bill'],
#  'mark.': ['[Bianca]'],
#  'hold': ['on.'],
#  'on.': ['[Ajax]', 'Guys.'],
#  '[Ajax]': ['Wait.', 'This', 'Enid?'],
#  'Wait.': ['Are', 'No,'],
#  'serious?': ['There’s'],
#  'There’s': ['only'],
#  'understands.': ['Pain.'],
#  'Pain.': ['Wait!'],
#  'Wait!': ['No,', 'Hey!'],
#  'No,': ['Wednesday!', 'I’m', 'don’t', 'no,', 'it’s', 'she', 'never.'],
#  'Wednesday!': ['Wednesday!', 'That’s', 'Eugene.', 'I'],
#  'out!': ['[Nightshade', '[keening'],
#  '[Nightshade': ['member]'],
#  'member]': ['Us'],
#  'Us': ['too.'],
#  'too.': ['No.', 'Let’s', 'Joseph', 'What'],
#  'No.': ['Wait.', 'I'],
#  'done.': ['Wednesday,', 'You'],
#  'sign': ['up', 'of'],
#  'this.': ['Let’s', 'I'],
#  'Let’s': ['go', 'test', 'go.', 'keep', 'go!'],
#  'go': ['to', 'back\xa0to', 'check', 'wait', 'all', 'look'],
#  'explain': ['everything.', 'on'],
#  'everything.': ['Weems', 'The', 'Initially', '©'],
#  'help.': ['And', 'Can’t', 'It’s'],
#  'always': ['one', 'been', 'believed', 'said,'],
#  'step': ['ahead'],
#  'ahead': ['of'],
#  'father.': ['Then'],
#  'own.': ['[Tyler'],
#  '[Tyler': ['panting]'],
#  'panting]': ['No,', '[Laurel'],
#  'here': ['with', 'to'],
#  'her,': ['please!', 'Dad.'],
#  'please!': ['I’m', '[grim,'],
#  'begging': ['you,'],
#  '[grim,': ['foreboding'],
#  'foreboding': ['music'],
#  '[tasers': ['sparking]'],
#  'sparking]': ['[jauntily'],
#  '[jauntily': ['macabre', 'macabre'],
#  'macabre': ['music', 'outro'],
#  '[Kinbott]': ['When'],
#  'press': ['him'],
#  'any': ['sensitive', 'of'],
#  'sensitive': ['issue,'],
#  'issue,': ['he'],
#  'snaps,': ['becoming'],
#  'becoming': ['cold'],
#  'cold': ['and'],
#  'detached.': ['It’s'],
#  'like': ['I’m', 'you,', 'a', 'a'],
#  'talking': ['to'],
#  'different': ['person.', 'approach.'],
#  'person.': ['I’m', 'Okay.'],
#  'increasingly': ['concerned.'],
#  'concerned.': ['I'],
#  'believe': ['the', 'you.', 'I’m', 'your', 'you’re'],
#  'trauma': ['of'],
#  'losing': ['his'],
#  'may': ['have', 'be'],
#  'left': ['Tyler', 'on', 'this'],
#  'deeper': ['psychological'],
#  'psychological': ['scars'],
#  'scars': ['than'],
#  'than': ['I', 'take', 'it', 'I', 'the'],
#  'suspected.': ['[cell'],
#  '[cell': ['phone'],
#  'phone': ['ringing]'],
#  'ringing]': ['[Galpin]'],
#  '[Galpin]': ['Hello?', 'Xavier', 'Quiet!'],
#  'Hello?': ['Sheriff'],
#  'Sheriff': ['Galpin.', 'Galpin', 'Galpin'],
#  'Galpin.': ['We'],
#  'problem.': ['And'],
#  'name': ['is\xa0Wednesday', 'is'],
#  'is\xa0Wednesday': ['Addams.'],
#  'Addams.': ['What', 'And', 'You', '[gentle,'],
#  'What': ['is',
#   'do',
#   'does',
#   'does',
#   'are',
#   'about',
#   'about',
#   'Tyler',
#   'they',
#   'happened?',
#   'the',
#   'about',
#   'does',
#   'about',
#   'the',
#   'demon'],
#  'Kinbott,': ['or'],
#  'should': ['I', 'hope', 'have', 'have', 'call', 'come'],
#  'say': ['Laurel', 'your'],
#  'Laurel': ['Gates,', 'said', 'Gates'],
#  'Gates,': ['using'],
#  'using': ['you', 'hypnosis'],
#  'for?': ['[weakly]', 'I'],
#  '[weakly]': ['Wednesday,'],
#  'please.': ['Tyler,'],
#  'Tyler,': ['the', 'honey,', 'go'],
#  'body': ['parts', 'parts.', 'parts'],
#  'parts': ['in', 'to'],
#  'basement': ['of'],
#  'collecting': ['them', 'these'],
#  'understand.': ['Why'],
#  'Why': ['are', 'would'],
#  'doing': ['this?', 'here?', 'in'],
#  'this?': ['[sirens', 'You', 'Then', 'Stay'],
#  '[sirens': ['wailing,'],
#  'wailing,': ['approaching]'],
#  'approaching]': ['Let’s', 'I'],
#  'test': ['your'],
#  'reflexes.': ['[Tyler]'],
#  'here!': ['Get', 'Now!'],
#  'Get': ['away', 'out.', 'a', 'them'],
#  'away': ['from', 'and', 'from'],
#  'son!': ['Drop'],
#  'Drop': ['it.', 'it.'],
#  '[hammer': ['clatters]'],
#  'clatters]': ['[officer]', '[arcane'],
#  '[officer]': ['Sign'],
#  'Sign': ['here.'],
#  '[indistinct': ['police'],
#  'radio': ['chatter]'],
#  'chatter]': ['Sheriff'],
#  'Galpin': ['isn’t', 'not', 'family'],
#  'isn’t': ['pressing', 'about'],
#  'pressing': ['kidnapping', 'charges'],
#  'kidnapping': ['charges.', 'and'],
#  'charges.': ['Which'],
#  'Which': ['is'],
#  'miracle': ['given'],
#  'given': ['the'],
#  'circumstances.': ['Of'],
#  'Of': ['course'],
#  'course': ['not.'],
#  'not.': ['How', 'You'],
#  'known?': ['Excuse'],
#  'Excuse': ['me?'],
#  'claw': ['from'],
#  'cave,': ['did'],
#  'did': ['you', 'to'],
#  'already': ['know?', 'is,'],
#  'know?': ['Wednesday,', 'I'],
#  'enough.': ['[Galpin]', 'Tyler,'],
#  'Thorpe': ['is'],
#  'our': ['Hyde.', 'relationship.', 'makeup', 'siren'],
#  'Hyde.': ['We’ve', 'And', 'Tyler', 'How', 'It’s', '[jittery,'],
#  'We’ve': ['got', 'got'],
#  'got': ['evidence,',
#   'me.',
#   'some',
#   'this,\xa0Wednesday.',
#   'a',
#   'to',
#   'to',
#   'going',
#   'to\xa0out-think',
#   'a'],
#  'evidence,': ['thanks'],
#  'thanks': ['to'],
#  'giving': ['you'],
#  'pass.': ['Tyler'],
#  'going': ['to', 'to', 'to', 'to', 'on?', 'on,', 'on', 'on?', 'to'],
#  'turn': ['on'],
#  'go.': ['Get', 'Leave!', 'Wednesday’s'],
#  'out.': ['We…'],
#  'We…': ['Wednesday,'],
#  'wait.': ['Tyler!', 'Wait!'],
#  'Tyler!': ['No,'],
#  'no,': ['what'],
#  'need': ['to', 'to', 'psychiatric', 'to', 'to'],
#  'talk': ['to'],
#  'Dad.': ['She'],
#  'friend.': ['We’re', 'Look'],
#  'We’re': ['in', 'sorry.', 'getting'],
#  'station.': ['What’s', '[Thing', 'Heard', 'Don’t'],
#  'happen?': ['Make'],
#  'Make': ['it'],
#  'quick.': ['What'],
#  'want?': ['To'],
#  'To': ['ask', 'lose.'],
#  'question.': ['What'],
#  'does': ['it', 'what', 'this'],
#  'feel': ['like?', 'like?', 'special'],
#  'like?': ['What', 'To'],
#  'lose.': ['[chilling'],
#  '[chilling': ['music', 'music'],
#  'know,': ['at', 'we', 'it’s', 'once'],
#  'first,': ['I’d', 'so'],
#  'I’d': ['wake', 'settle'],
#  'wake': ['up', 'the'],
#  'naked,': ['covered'],
#  'covered': ['in'],
#  'idea': ['what', 'what’s'],
#  'happened.': ['But', 'She’s'],
#  'over': ['time,', 'there'],
#  'time,': ['I', 'and', 'and', 'and'],
#  'started': ['to'],
#  'remember': ['everything.', 'her.', 'any'],
#  'The': ['sound',
#   'quid',
#   'others',
#   'plan',
#   'Nightshades',
#   'outcasts',
#   'supernatural.',
#   'one',
#   'tires',
#   'school'],
#  'screams,': ['the'],
#  'panic': ['in', 'and'],
#  'eyes,': ['and'],
#  'fear': ['so'],
#  'primal': ['I'],
#  'could': ['taste', 'believe', 'be', 'be', 'change'],
#  'taste': ['it.'],
#  'delicious.': ['You'],
#  'what’s': ['coming.', 'coming.', 'up?', 'the', 'coming.'],
#  'coming.': ['[music', 'I', 'Or', '[Kent]'],
#  '[music': ['swells,', 'swells]', 'builds]', 'intensifies]'],
#  'swells,': ['fades'],
#  'fades': ['away]', 'away]', 'away]'],
#  'away]': ['[barely', '[typewriter', '[Wednesday'],
#  '[barely': ['restrained'],
#  'restrained': ['seething]'],
#  'seething]': ['The', 'Kind'],
#  'quid': ['pro'],
#  'pro': ['quo'],
#  'quo': ['for'],
#  'charges': ['is', 'dismissed.'],
#  'immediate': ['expulsion'],
#  'expulsion': ['from'],
#  'others': ['had'],
#  'nothing': ['to'],
#  'acted': ['alone.'],
#  'alone.': ['For'],
#  'For': ['someone', 'that,'],
#  'someone': ['who', 'set', 'wearing'],
#  'claims': ['to'],
#  'friends,': ['you'],
#  'certainly': ['protect'],
#  'protect': ['them.', 'Ellie'],
#  'them.': ['They', 'Why', 'Thing'],
#  'They': ['didn’t', 'were', 'may'],
#  'guts': ['to'],
#  'needed': ['to'],
#  'be': ['done.',
#   'your',
#   'on',
#   'very',
#   'the',
#   'moving',
#   'a',
#   'ready',
#   'halfway',
#   'wild…',
#   'dangerous.',
#   'a',
#   'sacrificed.',
#   'swift',
#   'stabbed',
#   'vanquished',
#   'a',
#   'back',
#   'more',
#   'published.'],
#  'mean': ['kidnapping'],
#  'torture?': ['I'],
#  'hope': ['not.', 'you’re'],
#  'realize': ['that', 'is'],
#  'brutally': ['disemboweled'],
#  'disemboweled': ['six'],
#  'six': ['people,'],
#  'people,': ['then'],
#  'then': ['harvested', 'took'],
#  'harvested': ['a'],
#  'variety': ['of'],
#  'parts.': ['Perhaps'],
#  'you’d': ['come', 'be'],
#  'come': ['to', 'back.', 'true', 'from', 'visit', 'with', 'across'],
#  'suspicions': ['rather'],
#  'rather': ['than'],
#  'take': ['matters', 'a', 'me', 'it', 'an'],
#  'matters': ['into'],
#  'hands,': ['we'],
#  'could’ve': ['worked'],
#  'worked': ['together.'],
#  'together.': ['Because', '[somber'],
#  'Because': ['trust', 'she’s'],
#  'trust': ['and', 'your'],
#  'cooperation': ['have'],
#  'hallmarks': ['of'],
#  'relationship.': ['[weary'],
#  '[weary': ['chuckle]'],
#  '[gloomy': ['music'],
#  'admire': ['your'],
#  'ability': ['to'],
#  'person': ['and'],
#  'instincts.': ['But'],
#  'also': ['makes', 'symbolizes', 'a'],
#  'makes': ['you', 'my'],
#  'impatient': ['and'],
#  'impulsive.': ['Your'],
#  'actions': ['have'],
#  'school': ['in', 'full', 'to', 'needs'],
#  'impossible': ['position.'],
#  'position.': ['Tyler'],
#  'framed': ['Xavier.'],
#  'Xavier.': ['He', 'No,', 'Ugh.', 'Hey,'],
#  'confessed': ['everything'],
#  'everything': ['to', 'that’s'],
#  'me!': ['I'],
#  'wish': ['I'],
#  'His': ['mother'],
#  'student': ['here,'],
#  'here,': ['you'],
#  'must': ['remember', 'be', 'protect'],
#  'Hyde!': ['Yes,'],
#  'Yes,': ['Francois.', 'Dr.', 'Thing!'],
#  'Francois.': ['A'],
#  'A': ['lovely', 'fitting', 'living'],
#  'lovely': ['woman.'],
#  'woman.': ['I', 'She’s'],
#  'identified': ['as.'],
#  'as.': ['Then'],
#  'give': ['me', 'zero'],
#  'more': ['time,', 'time,', 'deals,', 'difficult', 'interesting', 'deadly'],
#  'prove': ['they'],
#  'Hydes.': ['There'],
#  'There': ['is', 'was'],
#  'deals,': ['Wednesday.'],
#  'Pack': ['your'],
#  'steamer': ['trunks.'],
#  'trunks.': ['We'],
#  'will': ['have',
#   'be',
#   'do',
#   'go',
#   'be',
#   'mine.',
#   'suffer',
#   'go',
#   'be',
#   'allow',
#   'never',
#   'get',
#   'not',
#   'cut',
#   'expunge',
#   'send',
#   'be',
#   'not'],
#  'shipped.': ['And'],
#  'goodbyes.': ['You’ll'],
#  'You’ll': ['be'],
#  'afternoon': ['train'],
#  'train': ['tomorrow.'],
#  'tomorrow.': ['I’m'],
#  'sorry': ['Nevermore'],
#  'work': ['out'],
#  'very': ['disappointed.', 'talented', 'first'],
#  'disappointed.': ['And'],
#  'I.': ['[lachrymose'],
#  '[lachrymose': ['music'],
#  '[Xavier': ['sighs]', 'kicking'],
#  'sighs]': ['Xavier…'],
#  'Xavier…': ['I’m'],
#  'much': ['time', 'from', 'better', 'guarantee'],
#  'time': ['we', 'you', 'I’m', 'to'],
#  'have.': ['Thing'],
#  'guards': ['and'],
#  'looping': ['the'],
#  'cameras.': ['What'],
#  'here?': ['I', 'How'],
#  'used': ['me', 'a', 'the'],
#  'frame': ['you.'],
#  'actual': ['Hyde.'],
#  'me.': ['[suspenseful', 'This', 'Remember', 'Now', 'Because,', 'Come', 'So…'],
#  '[suspenseful': ['music', 'music'],
#  'I’m…': ['glad'],
#  'glad': ['you', 'I'],
#  'getting': ['some', 'on', 'that'],
#  'action': ['while'],
#  'falsely': ['accused.'],
#  'accused.': ['I'],
#  'should’ve': ['believed'],
#  'believed': ['you.', 'relying'],
#  'since': ['you'],
#  'seem': ['to'],
#  'psychic': ['connection'],
#  'connection': ['to'],
#  'Hyde,': ['I'],
#  'curious': ['if'],
#  'you’ve': ['drawn', 'got', 'underestimated', 'made'],
#  'drawn': ['anything'],
#  'anything': ['that', 'for'],
#  'might': ['shed', 'not'],
#  'shed': ['light'],
#  'want': ['my', 'to', 'to', 'to'],
#  'help?': ['You'],
#  'ruined': ['my'],
#  'life!': ['No.'],
#  'tried': ['being'],
#  'Look': ['where'],
#  'This': ['isn’t', 'prophecy', 'is', 'time', 'is', 'will'],
#  'us,': ['Xavier.'],
#  'it’s': ['about', 'secret.', 'too', 'for'],
#  'you!': ['Every'],
#  'Every': ['time', 'damn'],
#  'involved,': ['people'],
#  'people': ['get', 'to', 'spend', 'are', 'who'],
#  'hurt.': ['You’re'],
#  'You’re': ['toxic.', 'right.', 'a', 'not', 'the', 'like'],
#  'toxic.': ['All'],
#  'All': ['you', 'right,', 'charges', 'rights'],
#  'ever': ['do', 'mention'],
#  'things': ['worse.'],
#  'worse.': ['Tyler'],
#  'bad': ['was', 'guy…', 'woman.', 'person.'],
#  'care!': ['Do'],
#  'stop': ['this?'],
#  'leave.': ['Go'],
#  'Go': ['far'],
#  'far': ['away'],
#  'understand?': ['That'],
#  'can’t': ['happen', 'believe', 'wait', 'go', 'wake', 'believe', 'tell'],
#  'happen': ['if'],
#  'save': ['everyone,'],
#  'everyone,': ['okay?'],
#  'okay?': ['So,', 'So,', 'You’re'],
#  'Leave!': ['[disbelieving'],
#  '[disbelieving': ['scoff]'],
#  '[tense': ['music', 'music'],
#  'builds,': ['fades'],
#  '[typewriter': ['dings]', 'keys'],
#  'dings]': ['[clasp'],
#  '[clasp': ['locks]'],
#  'locks]': ['I'],
#  'actually': ['going', 'called'],
#  'miss': ['your', 'our', 'Principal'],
#  'creepy,': ['lifeless'],
#  'lifeless': ['eyes'],
#  'waking': ['me'],
#  'up.': ['It', 'Permanently.'],
#  'It': ['won’t',
#   'also',
#   'would',
#   'is',
#   'could',
#   'wasn’t',
#   'is',
#   'is',
#   'is',
#   'will'],
#  'same': ['without', 'fate'],
#  'without': ['you.', 'consequences.'],
#  'assume': ['you’ll', 'he'],
#  'you’ll': ['be'],
#  'moving': ['in'],
#  'Yoko.': ['Leaving'],
#  'Leaving': ['me'],
#  'past.': ['Not'],
#  'Not': ['ever.', 'hugging', 'even'],
#  'ever.': ['What'],
#  'you?': ['Will', '[scoffs]', 'I', 'It', 'Have', 'Listen,', '[sharp'],
#  'Will': ['you', 'today’s'],
#  'forget': ['about'],
#  'Enid…': ['the'],
#  'mark': ['you'],
#  'indelible.': ['Anytime'],
#  'Anytime': ['I'],
#  'grow': ['nauseous'],
#  'nauseous': ['at'],
#  'sight': ['of'],
#  'rainbow': ['or'],
#  'pop': ['song', 'music'],
#  'song': ['that', 'to'],
#  'ears': ['bleed,'],
#  'bleed,': ['I’ll'],
#  'I’ll': ['think', 'explain', 'get', 'take'],
#  'think': ['of', 'we’re'],
#  '[subdued,': ['whimsical'],
#  'whimsical': ['music'],
#  'Thanks.': ['I'],
#  'guess.': ['I'],
#  'relying': ['on'],
#  'weakness.': ['That'],
#  'inevitably': ['they'],
#  'lead': ['me'],
#  'disappointment.': ['Turns', 'Are'],
#  'Turns': ['out'],
#  'I’ve': ['been', 'learned', 'been', 'got', 'got', 'tried.', 'longed'],
#  'kidding': ['me?'],
#  'learned': ['so'],
#  'Part': ['of'],
#  'admittedly': ['criminal'],
#  'criminal': ['behavior,'],
#  'but…': ['most'],
#  'most': ['people'],
#  'spend': ['their'],
#  'entire': ['lives'],
#  'lives': ['pretending'],
#  'pretending': ['to'],
#  'zero': ['effs,'],
#  'effs,': ['and'],
#  'literally': ['never'],
#  'eff': ['to'],
#  'give.': ['Any'],
#  'Any': ['chance'],
#  'chance': ['you’ve'],
#  'sort': ['of'],
#  'sneaky': ['plan'],
#  'plan': ['to', 'wasn’t', 'in'],
#  'elude': ['Weems?'],
#  'Weems?': ['Xavier’s', 'What'],
#  'Xavier’s': ['right.'],
#  'right.': ['This', 'Not', 'You'],
#  'prophecy': ['cannot'],
#  'cannot': ['come'],
#  'kills': ['me'],
#  'still': ['walking', 'out', 'at', 'beat?', 'lurking'],
#  'walking': ['around'],
#  'around': ['free.'],
#  'free.': ['If'],
#  'If': ['he', 'you', 'Enid’s'],
#  'tries': ['anything,'],
#  'anything,': ['we'],
#  'full': ['of', 'blood'],
#  'gorgons,': ['vampires,'],
#  'vampires,': ['and'],
#  'werewolves,': ['ready'],
#  'ready': ['and', 'for', 'to'],
#  'waiting.': ['We’ve'],
#  'this,\xa0Wednesday.': ['I'],
#  'promise.': ['On'],
#  'good': ['note,', 'little'],
#  'note,': ['I'],
#  'text': ['from', 'is,'],
#  'Eugene’s': ['moms.'],
#  'moms.': ['He'],
#  'woke': ['up'],
#  'Maybe': ['Weems’ll', 'we', 'this'],
#  'Weems’ll': ['let'],
#  'drop': ['by', 'the', 'Ellie'],
#  'way': ['to', 'back', 'he', 'to'],
#  '[Thing': ['snapping', 'sliding'],
#  'snapping': ['insistently]'],
#  'insistently]': ['I'],
#  'we’re': ['all', 'gonna…'],
#  'set.': ['[Enid]'],
#  '[Enid]': ['Thing,', 'Bianca,', 'She'],
#  'Thing,': ['I’m', 'I’m'],
#  'makeup': ['tutorials.'],
#  'tutorials.': ['And'],
#  'better': ['keep', 'now.'],
#  'keep': ['sending', 'moving.'],
#  'sending': ['me'],
#  'moisturizing': ['tips.'],
#  'tips.': ['Stay'],
#  'Stay': ['in', 'away'],
#  'touch,': ['okay?'],
#  'gonna…': ['You’re'],
#  'hugging': ['is'],
#  'our\xa0thing.': ['[dramatic'],
#  '[dramatic': ['music'],
#  'wasn’t': ['to', 'enough'],
#  'expelled.': ['We’re'],
#  'sorry.': ['The', 'It'],
#  'Nightshades': ['need', 'forever.'],
#  'Or': ['a'],
#  'lot': ['of', 'of…', 'of'],
#  'die.': ['I’m'],
#  'caught': ['you.'],
#  'weeding': ['my'],
#  'wolfsbane,': ['and'],
#  'completely': ['lost'],
#  'lost': ['track'],
#  'track': ['of'],
#  'time.': ['This', 'Don’t', 'I'],
#  'parting': ['gift.'],
#  'gift.': ['White'],
#  'White': ['oleander,'],
#  'oleander,': ['one'],
#  'nature’s': ['deadliest.'],
#  'deadliest.': ['It'],
#  'symbolizes': ['destiny'],
#  'destiny': ['and'],
#  'renewal.': ['You’re'],
#  'talented': ['young'],
#  'young': ['woman,'],
#  'woman,': ['Wednesday.'],
#  'wait': ['to', 'by'],
#  'next.': ['[Weems]'],
#  '[Weems]': ['Wednesday.'],
#  'personally': ['escorting'],
#  'escorting': ['you'],
#  'train.': ['I', 'I'],
#  'final': ['favor.'],
#  'favor.': ['[sighs]'],
#  '[sighs]': ['[Eugene]'],
#  '[Eugene]': ['Wednesday!'],
#  'Eugene.': ['Glad', 'That', '[music'],
#  'Glad': ['to'],
#  'awake.': ['I'],
#  'heard': ['you', 'a'],
#  'visited': ['all'],
#  'mention': ['it'],
#  'again.': ['[chuckles]', 'The'],
#  '[chuckles]': ['Listen,'],
#  'Listen,': ['I’ve', 'Principal', 'Crackstone'],
#  'meaning': ['to'],
#  'tell': ['you…', 'me.', 'you'],
#  'you…': ['I'],
#  'shouldn’t': ['have'],
#  'gone': ['to'],
#  'dance.': ['I'],
#  'dance': ['floor'],
#  'floor': ['calls,'],
#  'calls,': ['you'],
#  'gotta': ['answer.'],
#  'answer.': ['It’s'],
#  'fault.': ['It’s'],
#  'monster’s.': ['It’s'],
#  'called': ['a'],
#  'there.': ['You'],
#  'back\xa0to': ['Nevermore.'],
#  'even': ['to', 'for', 'Kent', 'more'],
#  'check': ['on', 'out'],
#  'bees.': ['And'],
#  'listen': ['to'],
#  'hummers': ['were'],
#  'supposed': ['to'],
#  'stick': ['together.', 'together,'],
#  '[somber': ['music'],
#  'woods,': ['someone'],
#  'set': ['fire', 'the'],
#  'fire': ['to', 'alarms?'],
#  'cave.': ['Yes,'],
#  'Dr.': ['Kinbott.'],
#  'crazy': ['that'],
#  'wearing': ['black'],
#  'black': ['and', 'heart.'],
#  'those': ['boots.', 'years'],
#  'boots.': ['What'],
#  'boots?': ['There'],
#  'explosion': ['of'],
#  'moment,': ['I', 'what'],
#  'weren’t': ['black.'],
#  ...}

# %%
def generate_sentence2(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    punc = ["'", '?','.',',',':',';','!','*','%','"','/']
    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2
        if word2[-1] in punc:
            return(sentence)

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ep08_dict)
# Out:
# 'Defeats Tyler with her methods, her true identity—Laurel Gates. However, Gates resurrects Crackstone must remember.'

# %%
generate_sentence2(ep08_dict)
# Out:
# 'Oleander, one can pretty much better now.'
